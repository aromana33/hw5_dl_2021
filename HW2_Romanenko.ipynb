# %% [markdown]
# <center><img src="https://github.com/hse-ds/iad-applied-ds/blob/master/2021/hw/hw1/img/logo_hse.png?raw=1" width="1000"></center>
#
# <h1><center>Прикладные задачи анализа данных</center></h1>
# <h2><center>Домашнее задание 2: Deep learning для обработки звука</center></h2>

# %% [markdown]
# # Введение
#
# В этом задании Вы поработаете и разберетесь в деталях с форматами представления аудиоданных в задачах глубинного обучения, а так же напишете несколько моделей для классификации аудиозаписей.
#
# В процессе выполнения Вы познакомитесь:
# * С алгоритмом построения Мел-спектрограммы.
# * Рекуррентными и сверточными классификаторами аудиоданных.
# * Алгоритмом аугментации аудиоданных SpecAugment.

# %%
# !pip install torch==1.8.0 torchaudio==0.8.0 numpy==1.20.0
# Out:
# Requirement already satisfied: torch==1.8.0 in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: torchaudio==0.8.0 in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy==1.20.0 in /usr/local/lib/python3.7/dist-packages (1.20.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0) (3.7.4.3)

# %%
# %matplotlib inline

from IPython import display
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, Subset

import torchaudio

assert torch.__version__.startswith('1.8.0')
assert torchaudio.__version__ == '0.8.0'

device='cuda:0'

# %% [markdown]
# # Классификация аудиозаписей.

# %% [markdown]
# В этом домашнем задании Вам предстоит классифицировать аудиозаписи из датасета [UrbanSound8K](https://urbansounddataset.weebly.com/urbansound8k.html).
#
# Данный датасет состоит из 8732 записей, разбитых на train/val/test датасеты.
#
# ![image](https://paperswithcode.com/media/datasets/UrbanSound8K-0000003722-02faef06.jpg)
#
# Каждая аудиозапись содержит запись шума города и принадлежит одному из 10 классов:
#
# `[air_conditioner, car_horn, children_playing, dog_bark, drilling, engine_idling, gun_shot, jackhammer, siren, street_music]`

# %% [markdown]
# ## Задание 1 (1 балл). Знакомство с данными.
#
# 1. Скачайте датасет из [Google Drive](https://drive.google.com/file/d/12emmtpodmo1783e6VOOEjV20zAKl5dZR/view?usp=sharing) c и распакуйте в папку `./data`.
#
# 2. Напишите `AudioDataset` класс, который будет принимать путь к файлам `train_part.csv` и `val_part.csv` и возращать тройки объектов `(x, y, len)`, где `x` - аудиозапись, `y` - класс аудиозаписи, `len` - длина аудиозаписи. Аудиозаписи **не должны постоянно храниться в RAM**, подгрузку _wav_ файлов надо сделать при запросе через `__getitem__` метод. Кроме того, надо сделать паддинг аудиозаписи - если она короче чем `pad_size` параметр, надо дополнять ее нулями.
#
# 3. С помощью функции `display.Audio` проиграйте в ноутбуке пару аудиозаписей.

# %%
# скачаем и распакуем данные
# !rm -r ./data
# !mkdir ./data/
# !pip install gdown
# !cd ./data && gdown https://drive.google.com/uc?id=18PoxCGG4k3mS6PiuomQY4jrdSfQaiajY && unzip HW2_dataset.zip && rm HW2_dataset.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: urbansound8k/data/1563.wav
#   inflating: __MACOSX/urbansound8k/data/._1563.wav
#   inflating: urbansound8k/data/7112.wav
#   inflating: __MACOSX/urbansound8k/data/._7112.wav
#   inflating: urbansound8k/data/8221.wav
#   inflating: __MACOSX/urbansound8k/data/._8221.wav
#   inflating: urbansound8k/data/5705.wav
#   inflating: __MACOSX/urbansound8k/data/._5705.wav
#   inflating: urbansound8k/data/5063.wav
#   inflating: __MACOSX/urbansound8k/data/._5063.wav
#   inflating: urbansound8k/data/7674.wav
#   inflating: __MACOSX/urbansound8k/data/._7674.wav
#   inflating: urbansound8k/data/8547.wav
#   inflating: __MACOSX/urbansound8k/data/._8547.wav
#   inflating: urbansound8k/data/791.wav
#   inflating: __MACOSX/urbansound8k/data/._791.wav
#   inflating: urbansound8k/data/1205.wav
#   inflating: __MACOSX/urbansound8k/data/._1205.wav
#   inflating: urbansound8k/data/6542.wav
#   inflating: __MACOSX/urbansound8k/data/._6542.wav
#   inflating: urbansound8k/data/6224.wav
#   inflating: __MACOSX/urbansound8k/data/._6224.wav
#   inflating: urbansound8k/data/4433.wav
#   inflating: __MACOSX/urbansound8k/data/._4433.wav
#   inflating: urbansound8k/data/2042.wav
#   inflating: __MACOSX/urbansound8k/data/._2042.wav
#   inflating: urbansound8k/data/4427.wav
#   inflating: __MACOSX/urbansound8k/data/._4427.wav
#   inflating: urbansound8k/data/2056.wav
#   inflating: __MACOSX/urbansound8k/data/._2056.wav
#   inflating: urbansound8k/data/5739.wav
#   inflating: __MACOSX/urbansound8k/data/._5739.wav
#   inflating: urbansound8k/data/6230.wav
#   inflating: __MACOSX/urbansound8k/data/._6230.wav
#   inflating: urbansound8k/data/975.wav
#   inflating: __MACOSX/urbansound8k/data/._975.wav
#   inflating: urbansound8k/data/7648.wav
#   inflating: __MACOSX/urbansound8k/data/._7648.wav
#   inflating: urbansound8k/data/7890.wav
#   inflating: __MACOSX/urbansound8k/data/._7890.wav
#   inflating: urbansound8k/data/6556.wav
#   inflating: __MACOSX/urbansound8k/data/._6556.wav
#   inflating: urbansound8k/data/2730.wav
#   inflating: __MACOSX/urbansound8k/data/._2730.wav
#   inflating: urbansound8k/data/4341.wav
#   inflating: __MACOSX/urbansound8k/data/._4341.wav
#   inflating: urbansound8k/data/222.wav
#   inflating: __MACOSX/urbansound8k/data/._222.wav
#   inflating: urbansound8k/data/6967.wav
#   inflating: __MACOSX/urbansound8k/data/._6967.wav
#   inflating: urbansound8k/data/544.wav
#   inflating: __MACOSX/urbansound8k/data/._544.wav
#   inflating: urbansound8k/data/6973.wav
#   inflating: __MACOSX/urbansound8k/data/._6973.wav
#   inflating: urbansound8k/data/236.wav
#   inflating: __MACOSX/urbansound8k/data/._236.wav
#   inflating: urbansound8k/data/1952.wav
#   inflating: __MACOSX/urbansound8k/data/._1952.wav
#   inflating: urbansound8k/data/3823.wav
#   inflating: __MACOSX/urbansound8k/data/._3823.wav
#   inflating: urbansound8k/data/6783.wav
#   inflating: __MACOSX/urbansound8k/data/._6783.wav
#   inflating: urbansound8k/data/578.wav
#   inflating: __MACOSX/urbansound8k/data/._578.wav
#   inflating: urbansound8k/data/6797.wav
#   inflating: __MACOSX/urbansound8k/data/._6797.wav
#   inflating: urbansound8k/data/4180.wav
#   inflating: __MACOSX/urbansound8k/data/._4180.wav
#   inflating: urbansound8k/data/3189.wav
#   inflating: __MACOSX/urbansound8k/data/._3189.wav
#   inflating: urbansound8k/data/2297.wav
#   inflating: __MACOSX/urbansound8k/data/._2297.wav
#   inflating: urbansound8k/data/1946.wav
#   inflating: __MACOSX/urbansound8k/data/._1946.wav
#   inflating: urbansound8k/data/8037.wav
#   inflating: __MACOSX/urbansound8k/data/._8037.wav
#   inflating: urbansound8k/data/5513.wav
#   inflating: __MACOSX/urbansound8k/data/._5513.wav
#   inflating: urbansound8k/data/3162.wav
#   inflating: __MACOSX/urbansound8k/data/._3162.wav
#   inflating: urbansound8k/data/3604.wav
#   inflating: __MACOSX/urbansound8k/data/._3604.wav
#   inflating: urbansound8k/data/587.wav
#   inflating: __MACOSX/urbansound8k/data/._587.wav
#   inflating: urbansound8k/data/7462.wav
#   inflating: __MACOSX/urbansound8k/data/._7462.wav
#   inflating: urbansound8k/data/6768.wav
#   inflating: __MACOSX/urbansound8k/data/._6768.wav
#   inflating: urbansound8k/data/1007.wav
#   inflating: __MACOSX/urbansound8k/data/._1007.wav
#   inflating: urbansound8k/data/593.wav
#   inflating: __MACOSX/urbansound8k/data/._593.wav
#   inflating: urbansound8k/data/7476.wav
#   inflating: __MACOSX/urbansound8k/data/._7476.wav
#   inflating: urbansound8k/data/3610.wav
#   inflating: __MACOSX/urbansound8k/data/._3610.wav
#   inflating: urbansound8k/data/5507.wav
#   inflating: __MACOSX/urbansound8k/data/._5507.wav
#   inflating: urbansound8k/data/3176.wav
#   inflating: __MACOSX/urbansound8k/data/._3176.wav
#   inflating: urbansound8k/data/4619.wav
#   inflating: __MACOSX/urbansound8k/data/._4619.wav
#   inflating: urbansound8k/data/1761.wav
#   inflating: __MACOSX/urbansound8k/data/._1761.wav
#   inflating: urbansound8k/data/2240.wav
#   inflating: __MACOSX/urbansound8k/data/._2240.wav
#   inflating: urbansound8k/data/7338.wav
#   inflating: __MACOSX/urbansound8k/data/._7338.wav
#   inflating: urbansound8k/data/1991.wav
#   inflating: __MACOSX/urbansound8k/data/._1991.wav
#   inflating: urbansound8k/data/1749.wav
#   inflating: __MACOSX/urbansound8k/data/._1749.wav
#   inflating: urbansound8k/data/6026.wav
#   inflating: __MACOSX/urbansound8k/data/._6026.wav
#   inflating: urbansound8k/data/6740.wav
#   inflating: __MACOSX/urbansound8k/data/._6740.wav
#   inflating: urbansound8k/data/6998.wav
#   inflating: __MACOSX/urbansound8k/data/._6998.wav
#   inflating: urbansound8k/data/2526.wav
#   inflating: __MACOSX/urbansound8k/data/._2526.wav
#   inflating: urbansound8k/data/4143.wav
#   inflating: __MACOSX/urbansound8k/data/._4143.wav
#   inflating: urbansound8k/data/2532.wav
#   inflating: __MACOSX/urbansound8k/data/._2532.wav
#   inflating: urbansound8k/data/6754.wav
#   inflating: __MACOSX/urbansound8k/data/._6754.wav
#   inflating: urbansound8k/data/2254.wav
#   inflating: __MACOSX/urbansound8k/data/._2254.wav
#   inflating: urbansound8k/data/4625.wav
#   inflating: __MACOSX/urbansound8k/data/._4625.wav
#   inflating: urbansound8k/data/2524.wav
#   inflating: __MACOSX/urbansound8k/data/._2524.wav
#   inflating: urbansound8k/data/4155.wav
#   inflating: __MACOSX/urbansound8k/data/._4155.wav
#   inflating: urbansound8k/data/6742.wav
#   inflating: __MACOSX/urbansound8k/data/._6742.wav
#   inflating: urbansound8k/data/8009.wav
#   inflating: __MACOSX/urbansound8k/data/._8009.wav
#   inflating: urbansound8k/data/4633.wav
#   inflating: __MACOSX/urbansound8k/data/._4633.wav
#   inflating: urbansound8k/data/3148.wav
#   inflating: __MACOSX/urbansound8k/data/._3148.wav
#   inflating: urbansound8k/data/2256.wav
#   inflating: __MACOSX/urbansound8k/data/._2256.wav
#   inflating: urbansound8k/data/6030.wav
#   inflating: __MACOSX/urbansound8k/data/._6030.wav
#   inflating: urbansound8k/data/1987.wav
#   inflating: __MACOSX/urbansound8k/data/._1987.wav
#   inflating: urbansound8k/data/7448.wav
#   inflating: __MACOSX/urbansound8k/data/._7448.wav
#   inflating: urbansound8k/data/7460.wav
#   inflating: __MACOSX/urbansound8k/data/._7460.wav
#   inflating: urbansound8k/data/585.wav
#   inflating: __MACOSX/urbansound8k/data/._585.wav
#   inflating: urbansound8k/data/5277.wav
#   inflating: __MACOSX/urbansound8k/data/._5277.wav
#   inflating: urbansound8k/data/3606.wav
#   inflating: __MACOSX/urbansound8k/data/._3606.wav
#   inflating: urbansound8k/data/4169.wav
#   inflating: __MACOSX/urbansound8k/data/._4169.wav
#   inflating: urbansound8k/data/3160.wav
#   inflating: __MACOSX/urbansound8k/data/._3160.wav
#   inflating: urbansound8k/data/5511.wav
#   inflating: __MACOSX/urbansound8k/data/._5511.wav
#   inflating: urbansound8k/data/1777.wav
#   inflating: __MACOSX/urbansound8k/data/._1777.wav
#   inflating: urbansound8k/data/8035.wav
#   inflating: __MACOSX/urbansound8k/data/._8035.wav
#   inflating: urbansound8k/data/1763.wav
#   inflating: __MACOSX/urbansound8k/data/._1763.wav
#   inflating: urbansound8k/data/8021.wav
#   inflating: __MACOSX/urbansound8k/data/._8021.wav
#   inflating: urbansound8k/data/5505.wav
#   inflating: __MACOSX/urbansound8k/data/._5505.wav
#   inflating: urbansound8k/data/5263.wav
#   inflating: __MACOSX/urbansound8k/data/._5263.wav
#   inflating: urbansound8k/data/6781.wav
#   inflating: __MACOSX/urbansound8k/data/._6781.wav
#   inflating: urbansound8k/data/3821.wav
#   inflating: __MACOSX/urbansound8k/data/._3821.wav
#   inflating: urbansound8k/data/4828.wav
#   inflating: __MACOSX/urbansound8k/data/._4828.wav
#   inflating: urbansound8k/data/1950.wav
#   inflating: __MACOSX/urbansound8k/data/._1950.wav
#   inflating: urbansound8k/data/1944.wav
#   inflating: __MACOSX/urbansound8k/data/._1944.wav
#   inflating: urbansound8k/data/208.wav
#   inflating: __MACOSX/urbansound8k/data/._208.wav
#   inflating: urbansound8k/data/2295.wav
#   inflating: __MACOSX/urbansound8k/data/._2295.wav
#   inflating: urbansound8k/data/4182.wav
#   inflating: __MACOSX/urbansound8k/data/._4182.wav
#   inflating: urbansound8k/data/6965.wav
#   inflating: __MACOSX/urbansound8k/data/._6965.wav
#   inflating: urbansound8k/data/4800.wav
#   inflating: __MACOSX/urbansound8k/data/._4800.wav
#   inflating: urbansound8k/data/1978.wav
#   inflating: __MACOSX/urbansound8k/data/._1978.wav
#   inflating: urbansound8k/data/6971.wav
#   inflating: __MACOSX/urbansound8k/data/._6971.wav
#   inflating: urbansound8k/data/2040.wav
#   inflating: __MACOSX/urbansound8k/data/._2040.wav
#   inflating: urbansound8k/data/4431.wav
#   inflating: __MACOSX/urbansound8k/data/._4431.wav
#   inflating: urbansound8k/data/7138.wav
#   inflating: __MACOSX/urbansound8k/data/._7138.wav
#   inflating: urbansound8k/data/1549.wav
#   inflating: __MACOSX/urbansound8k/data/._1549.wav
#   inflating: urbansound8k/data/963.wav
#   inflating: __MACOSX/urbansound8k/data/._963.wav
#   inflating: urbansound8k/data/2726.wav
#   inflating: __MACOSX/urbansound8k/data/._2726.wav
#   inflating: urbansound8k/data/5049.wav
#   inflating: __MACOSX/urbansound8k/data/._5049.wav
#   inflating: urbansound8k/data/2732.wav
#   inflating: __MACOSX/urbansound8k/data/._2732.wav
#   inflating: urbansound8k/data/7892.wav
#   inflating: __MACOSX/urbansound8k/data/._7892.wav
#   inflating: urbansound8k/data/977.wav
#   inflating: __MACOSX/urbansound8k/data/._977.wav
#   inflating: urbansound8k/data/8579.wav
#   inflating: __MACOSX/urbansound8k/data/._8579.wav
#   inflating: urbansound8k/data/6232.wav
#   inflating: __MACOSX/urbansound8k/data/._6232.wav
#   inflating: urbansound8k/data/2054.wav
#   inflating: __MACOSX/urbansound8k/data/._2054.wav
#   inflating: urbansound8k/data/4425.wav
#   inflating: __MACOSX/urbansound8k/data/._4425.wav
#   inflating: urbansound8k/data/5713.wav
#   inflating: __MACOSX/urbansound8k/data/._5713.wav
#   inflating: urbansound8k/data/3362.wav
#   inflating: __MACOSX/urbansound8k/data/._3362.wav
#   inflating: urbansound8k/data/3404.wav
#   inflating: __MACOSX/urbansound8k/data/._3404.wav
#   inflating: urbansound8k/data/5075.wav
#   inflating: __MACOSX/urbansound8k/data/._5075.wav
#   inflating: urbansound8k/data/787.wav
#   inflating: __MACOSX/urbansound8k/data/._787.wav
#   inflating: urbansound8k/data/6568.wav
#   inflating: __MACOSX/urbansound8k/data/._6568.wav
#   inflating: urbansound8k/data/5707.wav
#   inflating: __MACOSX/urbansound8k/data/._5707.wav
#   inflating: urbansound8k/data/3376.wav
#   inflating: __MACOSX/urbansound8k/data/._3376.wav
#   inflating: urbansound8k/data/7110.wav
#   inflating: __MACOSX/urbansound8k/data/._7110.wav
#   inflating: urbansound8k/data/1561.wav
#   inflating: __MACOSX/urbansound8k/data/._1561.wav
#   inflating: urbansound8k/data/5934.wav
#   inflating: __MACOSX/urbansound8k/data/._5934.wav
#   inflating: urbansound8k/data/2083.wav
#   inflating: __MACOSX/urbansound8k/data/._2083.wav
#   inflating: urbansound8k/data/4394.wav
#   inflating: __MACOSX/urbansound8k/data/._4394.wav
#   inflating: urbansound8k/data/6583.wav
#   inflating: __MACOSX/urbansound8k/data/._6583.wav
#   inflating: urbansound8k/data/778.wav
#   inflating: __MACOSX/urbansound8k/data/._778.wav
#   inflating: urbansound8k/data/7845.wav
#   inflating: __MACOSX/urbansound8k/data/._7845.wav
#   inflating: urbansound8k/data/7689.wav
#   inflating: __MACOSX/urbansound8k/data/._7689.wav
#   inflating: urbansound8k/data/2929.wav
#   inflating: __MACOSX/urbansound8k/data/._2929.wav
#   inflating: urbansound8k/data/3389.wav
#   inflating: __MACOSX/urbansound8k/data/._3389.wav
#   inflating: urbansound8k/data/5908.wav
#   inflating: __MACOSX/urbansound8k/data/._5908.wav
#   inflating: urbansound8k/data/7879.wav
#   inflating: __MACOSX/urbansound8k/data/._7879.wav
#   inflating: urbansound8k/data/744.wav
#   inflating: __MACOSX/urbansound8k/data/._744.wav
#   inflating: urbansound8k/data/2901.wav
#   inflating: __MACOSX/urbansound8k/data/._2901.wav
#   inflating: urbansound8k/data/2915.wav
#   inflating: __MACOSX/urbansound8k/data/._2915.wav
#   inflating: urbansound8k/data/8586.wav
#   inflating: __MACOSX/urbansound8k/data/._8586.wav
#   inflating: urbansound8k/data/750.wav
#   inflating: __MACOSX/urbansound8k/data/._750.wav
#   inflating: urbansound8k/data/4545.wav
#   inflating: __MACOSX/urbansound8k/data/._4545.wav
#   inflating: urbansound8k/data/2134.wav
#   inflating: __MACOSX/urbansound8k/data/._2134.wav
#   inflating: urbansound8k/data/817.wav
#   inflating: __MACOSX/urbansound8k/data/._817.wav
#   inflating: urbansound8k/data/8419.wav
#   inflating: __MACOSX/urbansound8k/data/._8419.wav
#   inflating: urbansound8k/data/57.wav
#   inflating: __MACOSX/urbansound8k/data/._57.wav
#   inflating: urbansound8k/data/6434.wav
#   inflating: __MACOSX/urbansound8k/data/._6434.wav
#   inflating: urbansound8k/data/2652.wav
#   inflating: __MACOSX/urbansound8k/data/._2652.wav
#   inflating: urbansound8k/data/5129.wav
#   inflating: __MACOSX/urbansound8k/data/._5129.wav
#   inflating: urbansound8k/data/2646.wav
#   inflating: __MACOSX/urbansound8k/data/._2646.wav
#   inflating: urbansound8k/data/803.wav
#   inflating: __MACOSX/urbansound8k/data/._803.wav
#   inflating: urbansound8k/data/6420.wav
#   inflating: __MACOSX/urbansound8k/data/._6420.wav
#   inflating: urbansound8k/data/43.wav
#   inflating: __MACOSX/urbansound8k/data/._43.wav
#   inflating: urbansound8k/data/6346.wav
#   inflating: __MACOSX/urbansound8k/data/._6346.wav
#   inflating: urbansound8k/data/5897.wav
#   inflating: __MACOSX/urbansound8k/data/._5897.wav
#   inflating: urbansound8k/data/7070.wav
#   inflating: __MACOSX/urbansound8k/data/._7070.wav
#   inflating: urbansound8k/data/3216.wav
#   inflating: __MACOSX/urbansound8k/data/._3216.wav
#   inflating: urbansound8k/data/2108.wav
#   inflating: __MACOSX/urbansound8k/data/._2108.wav
#   inflating: urbansound8k/data/8425.wav
#   inflating: __MACOSX/urbansound8k/data/._8425.wav
#   inflating: urbansound8k/data/1367.wav
#   inflating: __MACOSX/urbansound8k/data/._1367.wav
#   inflating: urbansound8k/data/6408.wav
#   inflating: __MACOSX/urbansound8k/data/._6408.wav
#   inflating: urbansound8k/data/7702.wav
#   inflating: __MACOSX/urbansound8k/data/._7702.wav
#   inflating: urbansound8k/data/8431.wav
#   inflating: __MACOSX/urbansound8k/data/._8431.wav
#   inflating: urbansound8k/data/3202.wav
#   inflating: __MACOSX/urbansound8k/data/._3202.wav
#   inflating: urbansound8k/data/5673.wav
#   inflating: __MACOSX/urbansound8k/data/._5673.wav
#   inflating: urbansound8k/data/1415.wav
#   inflating: __MACOSX/urbansound8k/data/._1415.wav
#   inflating: urbansound8k/data/7064.wav
#   inflating: __MACOSX/urbansound8k/data/._7064.wav
#   inflating: urbansound8k/data/8357.wav
#   inflating: __MACOSX/urbansound8k/data/._8357.wav
#   inflating: urbansound8k/data/5698.wav
#   inflating: __MACOSX/urbansound8k/data/._5698.wav
#   inflating: urbansound8k/data/5840.wav
#   inflating: __MACOSX/urbansound8k/data/._5840.wav
#   inflating: urbansound8k/data/2849.wav
#   inflating: __MACOSX/urbansound8k/data/._2849.wav
#   inflating: urbansound8k/data/2691.wav
#   inflating: __MACOSX/urbansound8k/data/._2691.wav
#   inflating: urbansound8k/data/1398.wav
#   inflating: __MACOSX/urbansound8k/data/._1398.wav
#   inflating: urbansound8k/data/7931.wav
#   inflating: __MACOSX/urbansound8k/data/._7931.wav
#   inflating: urbansound8k/data/80.wav
#   inflating: __MACOSX/urbansound8k/data/._80.wav
#   inflating: urbansound8k/data/2685.wav
#   inflating: __MACOSX/urbansound8k/data/._2685.wav
#   inflating: urbansound8k/data/4592.wav
#   inflating: __MACOSX/urbansound8k/data/._4592.wav
#   inflating: urbansound8k/data/5854.wav
#   inflating: __MACOSX/urbansound8k/data/._5854.wav
#   inflating: urbansound8k/data/8380.wav
#   inflating: __MACOSX/urbansound8k/data/._8380.wav
#   inflating: urbansound8k/data/630.wav
#   inflating: __MACOSX/urbansound8k/data/._630.wav
#   inflating: urbansound8k/data/2875.wav
#   inflating: __MACOSX/urbansound8k/data/._2875.wav
#   inflating: urbansound8k/data/7919.wav
#   inflating: __MACOSX/urbansound8k/data/._7919.wav
#   inflating: urbansound8k/data/624.wav
#   inflating: __MACOSX/urbansound8k/data/._624.wav
#   inflating: urbansound8k/data/142.wav
#   inflating: __MACOSX/urbansound8k/data/._142.wav
#   inflating: urbansound8k/data/4021.wav
#   inflating: __MACOSX/urbansound8k/data/._4021.wav
#   inflating: urbansound8k/data/2450.wav
#   inflating: __MACOSX/urbansound8k/data/._2450.wav
#   inflating: urbansound8k/data/7528.wav
#   inflating: __MACOSX/urbansound8k/data/._7528.wav
#   inflating: urbansound8k/data/5459.wav
#   inflating: __MACOSX/urbansound8k/data/._5459.wav
#   inflating: urbansound8k/data/4747.wav
#   inflating: __MACOSX/urbansound8k/data/._4747.wav
#   inflating: urbansound8k/data/4753.wav
#   inflating: __MACOSX/urbansound8k/data/._4753.wav
#   inflating: urbansound8k/data/6144.wav
#   inflating: __MACOSX/urbansound8k/data/._6144.wav
#   inflating: urbansound8k/data/2444.wav
#   inflating: __MACOSX/urbansound8k/data/._2444.wav
#   inflating: urbansound8k/data/3982.wav
#   inflating: __MACOSX/urbansound8k/data/._3982.wav
#   inflating: urbansound8k/data/8627.wav
#   inflating: __MACOSX/urbansound8k/data/._8627.wav
#   inflating: urbansound8k/data/3772.wav
#   inflating: __MACOSX/urbansound8k/data/._3772.wav
#   inflating: urbansound8k/data/5465.wav
#   inflating: __MACOSX/urbansound8k/data/._5465.wav
#   inflating: urbansound8k/data/3014.wav
#   inflating: __MACOSX/urbansound8k/data/._3014.wav
#   inflating: urbansound8k/data/7272.wav
#   inflating: __MACOSX/urbansound8k/data/._7272.wav
#   inflating: urbansound8k/data/1603.wav
#   inflating: __MACOSX/urbansound8k/data/._1603.wav
#   inflating: urbansound8k/data/397.wav
#   inflating: __MACOSX/urbansound8k/data/._397.wav
#   inflating: urbansound8k/data/8155.wav
#   inflating: __MACOSX/urbansound8k/data/._8155.wav
#   inflating: urbansound8k/data/383.wav
#   inflating: __MACOSX/urbansound8k/data/._383.wav
#   inflating: urbansound8k/data/4009.wav
#   inflating: __MACOSX/urbansound8k/data/._4009.wav
#   inflating: urbansound8k/data/3766.wav
#   inflating: __MACOSX/urbansound8k/data/._3766.wav
#   inflating: urbansound8k/data/2478.wav
#   inflating: __MACOSX/urbansound8k/data/._2478.wav
#   inflating: urbansound8k/data/7500.wav
#   inflating: __MACOSX/urbansound8k/data/._7500.wav
#   inflating: urbansound8k/data/2493.wav
#   inflating: __MACOSX/urbansound8k/data/._2493.wav
#   inflating: urbansound8k/data/3955.wav
#   inflating: __MACOSX/urbansound8k/data/._3955.wav
#   inflating: urbansound8k/data/4784.wav
#   inflating: __MACOSX/urbansound8k/data/._4784.wav
#   inflating: urbansound8k/data/368.wav
#   inflating: __MACOSX/urbansound8k/data/._368.wav
#   inflating: urbansound8k/data/6193.wav
#   inflating: __MACOSX/urbansound8k/data/._6193.wav
#   inflating: urbansound8k/data/6187.wav
#   inflating: __MACOSX/urbansound8k/data/._6187.wav
#   inflating: urbansound8k/data/1830.wav
#   inflating: __MACOSX/urbansound8k/data/._1830.wav
#   inflating: urbansound8k/data/4790.wav
#   inflating: __MACOSX/urbansound8k/data/._4790.wav
#   inflating: urbansound8k/data/4948.wav
#   inflating: __MACOSX/urbansound8k/data/._4948.wav
#   inflating: urbansound8k/data/2487.wav
#   inflating: __MACOSX/urbansound8k/data/._2487.wav
#   inflating: urbansound8k/data/3941.wav
#   inflating: __MACOSX/urbansound8k/data/._3941.wav
#   inflating: urbansound8k/data/3799.wav
#   inflating: __MACOSX/urbansound8k/data/._3799.wav
#   inflating: urbansound8k/data/6839.wav
#   inflating: __MACOSX/urbansound8k/data/._6839.wav
#   inflating: urbansound8k/data/3969.wav
#   inflating: __MACOSX/urbansound8k/data/._3969.wav
#   inflating: urbansound8k/data/6811.wav
#   inflating: __MACOSX/urbansound8k/data/._6811.wav
#   inflating: urbansound8k/data/354.wav
#   inflating: __MACOSX/urbansound8k/data/._354.wav
#   inflating: urbansound8k/data/1818.wav
#   inflating: __MACOSX/urbansound8k/data/._1818.wav
#   inflating: urbansound8k/data/8182.wav
#   inflating: __MACOSX/urbansound8k/data/._8182.wav
#   inflating: urbansound8k/data/4960.wav
#   inflating: __MACOSX/urbansound8k/data/._4960.wav
#   inflating: urbansound8k/data/4974.wav
#   inflating: __MACOSX/urbansound8k/data/._4974.wav
#   inflating: urbansound8k/data/426.wav
#   inflating: __MACOSX/urbansound8k/data/._426.wav
#   inflating: urbansound8k/data/427.wav
#   inflating: __MACOSX/urbansound8k/data/._427.wav
#   inflating: urbansound8k/data/6804.wav
#   inflating: __MACOSX/urbansound8k/data/._6804.wav
#   inflating: urbansound8k/data/6810.wav
#   inflating: __MACOSX/urbansound8k/data/._6810.wav
#   inflating: urbansound8k/data/3968.wav
#   inflating: __MACOSX/urbansound8k/data/._3968.wav
#   inflating: urbansound8k/data/4961.wav
#   inflating: __MACOSX/urbansound8k/data/._4961.wav
#   inflating: urbansound8k/data/1819.wav
#   inflating: __MACOSX/urbansound8k/data/._1819.wav
#   inflating: urbansound8k/data/8183.wav
#   inflating: __MACOSX/urbansound8k/data/._8183.wav
#   inflating: urbansound8k/data/355.wav
#   inflating: __MACOSX/urbansound8k/data/._355.wav
#   inflating: urbansound8k/data/4791.wav
#   inflating: __MACOSX/urbansound8k/data/._4791.wav
#   inflating: urbansound8k/data/1831.wav
#   inflating: __MACOSX/urbansound8k/data/._1831.wav
#   inflating: urbansound8k/data/7298.wav
#   inflating: __MACOSX/urbansound8k/data/._7298.wav
#   inflating: urbansound8k/data/3798.wav
#   inflating: __MACOSX/urbansound8k/data/._3798.wav
#   inflating: urbansound8k/data/3940.wav
#   inflating: __MACOSX/urbansound8k/data/._3940.wav
#   inflating: urbansound8k/data/1825.wav
#   inflating: __MACOSX/urbansound8k/data/._1825.wav
#   inflating: urbansound8k/data/369.wav
#   inflating: __MACOSX/urbansound8k/data/._369.wav
#   inflating: urbansound8k/data/4785.wav
#   inflating: __MACOSX/urbansound8k/data/._4785.wav
#   inflating: urbansound8k/data/3001.wav
#   inflating: __MACOSX/urbansound8k/data/._3001.wav
#   inflating: urbansound8k/data/6179.wav
#   inflating: __MACOSX/urbansound8k/data/._6179.wav
#   inflating: urbansound8k/data/1616.wav
#   inflating: __MACOSX/urbansound8k/data/._1616.wav
#   inflating: urbansound8k/data/382.wav
#   inflating: __MACOSX/urbansound8k/data/._382.wav
#   inflating: urbansound8k/data/8154.wav
#   inflating: __MACOSX/urbansound8k/data/._8154.wav
#   inflating: urbansound8k/data/7501.wav
#   inflating: __MACOSX/urbansound8k/data/._7501.wav
#   inflating: urbansound8k/data/8632.wav
#   inflating: __MACOSX/urbansound8k/data/._8632.wav
#   inflating: urbansound8k/data/5316.wav
#   inflating: __MACOSX/urbansound8k/data/._5316.wav
#   inflating: urbansound8k/data/2479.wav
#   inflating: __MACOSX/urbansound8k/data/._2479.wav
#   inflating: urbansound8k/data/5302.wav
#   inflating: __MACOSX/urbansound8k/data/._5302.wav
#   inflating: urbansound8k/data/8626.wav
#   inflating: __MACOSX/urbansound8k/data/._8626.wav
#   inflating: urbansound8k/data/396.wav
#   inflating: __MACOSX/urbansound8k/data/._396.wav
#   inflating: urbansound8k/data/1602.wav
#   inflating: __MACOSX/urbansound8k/data/._1602.wav
#   inflating: urbansound8k/data/8140.wav
#   inflating: __MACOSX/urbansound8k/data/._8140.wav
#   inflating: urbansound8k/data/6145.wav
#   inflating: __MACOSX/urbansound8k/data/._6145.wav
#   inflating: urbansound8k/data/8168.wav
#   inflating: __MACOSX/urbansound8k/data/._8168.wav
#   inflating: urbansound8k/data/4752.wav
#   inflating: __MACOSX/urbansound8k/data/._4752.wav
#   inflating: urbansound8k/data/2323.wav
#   inflating: __MACOSX/urbansound8k/data/._2323.wav
#   inflating: urbansound8k/data/3983.wav
#   inflating: __MACOSX/urbansound8k/data/._3983.wav
#   inflating: urbansound8k/data/2445.wav
#   inflating: __MACOSX/urbansound8k/data/._2445.wav
#   inflating: urbansound8k/data/6623.wav
#   inflating: __MACOSX/urbansound8k/data/._6623.wav
#   inflating: urbansound8k/data/7529.wav
#   inflating: __MACOSX/urbansound8k/data/._7529.wav
#   inflating: urbansound8k/data/1158.wav
#   inflating: __MACOSX/urbansound8k/data/._1158.wav
#   inflating: urbansound8k/data/6637.wav
#   inflating: __MACOSX/urbansound8k/data/._6637.wav
#   inflating: urbansound8k/data/3997.wav
#   inflating: __MACOSX/urbansound8k/data/._3997.wav
#   inflating: urbansound8k/data/4746.wav
#   inflating: __MACOSX/urbansound8k/data/._4746.wav
#   inflating: urbansound8k/data/6151.wav
#   inflating: __MACOSX/urbansound8k/data/._6151.wav
#   inflating: urbansound8k/data/7918.wav
#   inflating: __MACOSX/urbansound8k/data/._7918.wav
#   inflating: urbansound8k/data/5869.wav
#   inflating: __MACOSX/urbansound8k/data/._5869.wav
#   inflating: urbansound8k/data/8395.wav
#   inflating: __MACOSX/urbansound8k/data/._8395.wav
#   inflating: urbansound8k/data/8381.wav
#   inflating: __MACOSX/urbansound8k/data/._8381.wav
#   inflating: urbansound8k/data/631.wav
#   inflating: __MACOSX/urbansound8k/data/._631.wav
#   inflating: urbansound8k/data/2684.wav
#   inflating: __MACOSX/urbansound8k/data/._2684.wav
#   inflating: urbansound8k/data/81.wav
#   inflating: __MACOSX/urbansound8k/data/._81.wav
#   inflating: urbansound8k/data/619.wav
#   inflating: __MACOSX/urbansound8k/data/._619.wav
#   inflating: urbansound8k/data/5841.wav
#   inflating: __MACOSX/urbansound8k/data/._5841.wav
#   inflating: urbansound8k/data/5699.wav
#   inflating: __MACOSX/urbansound8k/data/._5699.wav
#   inflating: urbansound8k/data/7930.wav
#   inflating: __MACOSX/urbansound8k/data/._7930.wav
#   inflating: urbansound8k/data/1399.wav
#   inflating: __MACOSX/urbansound8k/data/._1399.wav
#   inflating: urbansound8k/data/2690.wav
#   inflating: __MACOSX/urbansound8k/data/._2690.wav
#   inflating: urbansound8k/data/5114.wav
#   inflating: __MACOSX/urbansound8k/data/._5114.wav
#   inflating: urbansound8k/data/8430.wav
#   inflating: __MACOSX/urbansound8k/data/._8430.wav
#   inflating: urbansound8k/data/8356.wav
#   inflating: __MACOSX/urbansound8k/data/._8356.wav
#   inflating: urbansound8k/data/7065.wav
#   inflating: __MACOSX/urbansound8k/data/._7065.wav
#   inflating: urbansound8k/data/1414.wav
#   inflating: __MACOSX/urbansound8k/data/._1414.wav
#   inflating: urbansound8k/data/5672.wav
#   inflating: __MACOSX/urbansound8k/data/._5672.wav
#   inflating: urbansound8k/data/4578.wav
#   inflating: __MACOSX/urbansound8k/data/._4578.wav
#   inflating: urbansound8k/data/1400.wav
#   inflating: __MACOSX/urbansound8k/data/._1400.wav
#   inflating: urbansound8k/data/6409.wav
#   inflating: __MACOSX/urbansound8k/data/._6409.wav
#   inflating: urbansound8k/data/1366.wav
#   inflating: __MACOSX/urbansound8k/data/._1366.wav
#   inflating: urbansound8k/data/8424.wav
#   inflating: __MACOSX/urbansound8k/data/._8424.wav
#   inflating: urbansound8k/data/5100.wav
#   inflating: __MACOSX/urbansound8k/data/._5100.wav
#   inflating: urbansound8k/data/42.wav
#   inflating: __MACOSX/urbansound8k/data/._42.wav
#   inflating: urbansound8k/data/802.wav
#   inflating: __MACOSX/urbansound8k/data/._802.wav
#   inflating: urbansound8k/data/4236.wav
#   inflating: __MACOSX/urbansound8k/data/._4236.wav
#   inflating: urbansound8k/data/2647.wav
#   inflating: __MACOSX/urbansound8k/data/._2647.wav
#   inflating: urbansound8k/data/5128.wav
#   inflating: __MACOSX/urbansound8k/data/._5128.wav
#   inflating: urbansound8k/data/2121.wav
#   inflating: __MACOSX/urbansound8k/data/._2121.wav
#   inflating: urbansound8k/data/7059.wav
#   inflating: __MACOSX/urbansound8k/data/._7059.wav
#   inflating: urbansound8k/data/1428.wav
#   inflating: __MACOSX/urbansound8k/data/._1428.wav
#   inflating: urbansound8k/data/6347.wav
#   inflating: __MACOSX/urbansound8k/data/._6347.wav
#   inflating: urbansound8k/data/2135.wav
#   inflating: __MACOSX/urbansound8k/data/._2135.wav
#   inflating: urbansound8k/data/4.wav
#   inflating: __MACOSX/urbansound8k/data/._4.wav
#   inflating: urbansound8k/data/5882.wav
#   inflating: __MACOSX/urbansound8k/data/._5882.wav
#   inflating: urbansound8k/data/4222.wav
#   inflating: __MACOSX/urbansound8k/data/._4222.wav
#   inflating: urbansound8k/data/2653.wav
#   inflating: __MACOSX/urbansound8k/data/._2653.wav
#   inflating: urbansound8k/data/56.wav
#   inflating: __MACOSX/urbansound8k/data/._56.wav
#   inflating: urbansound8k/data/6435.wav
#   inflating: __MACOSX/urbansound8k/data/._6435.wav
#   inflating: urbansound8k/data/816.wav
#   inflating: __MACOSX/urbansound8k/data/._816.wav
#   inflating: urbansound8k/data/751.wav
#   inflating: __MACOSX/urbansound8k/data/._751.wav
#   inflating: urbansound8k/data/8587.wav
#   inflating: __MACOSX/urbansound8k/data/._8587.wav
#   inflating: urbansound8k/data/2914.wav
#   inflating: __MACOSX/urbansound8k/data/._2914.wav
#   inflating: urbansound8k/data/5909.wav
#   inflating: __MACOSX/urbansound8k/data/._5909.wav
#   inflating: urbansound8k/data/2900.wav
#   inflating: __MACOSX/urbansound8k/data/._2900.wav
#   inflating: urbansound8k/data/2928.wav
#   inflating: __MACOSX/urbansound8k/data/._2928.wav
#   inflating: urbansound8k/data/4381.wav
#   inflating: __MACOSX/urbansound8k/data/._4381.wav
#   inflating: urbansound8k/data/7850.wav
#   inflating: __MACOSX/urbansound8k/data/._7850.wav
#   inflating: urbansound8k/data/6596.wav
#   inflating: __MACOSX/urbansound8k/data/._6596.wav
#   inflating: urbansound8k/data/7688.wav
#   inflating: __MACOSX/urbansound8k/data/._7688.wav
#   inflating: urbansound8k/data/2096.wav
#   inflating: __MACOSX/urbansound8k/data/._2096.wav
#   inflating: urbansound8k/data/3388.wav
#   inflating: __MACOSX/urbansound8k/data/._3388.wav
#   inflating: urbansound8k/data/5921.wav
#   inflating: __MACOSX/urbansound8k/data/._5921.wav
#   inflating: urbansound8k/data/2082.wav
#   inflating: __MACOSX/urbansound8k/data/._2082.wav
#   inflating: urbansound8k/data/7844.wav
#   inflating: __MACOSX/urbansound8k/data/._7844.wav
#   inflating: urbansound8k/data/5060.wav
#   inflating: __MACOSX/urbansound8k/data/._5060.wav
#   inflating: urbansound8k/data/8544.wav
#   inflating: __MACOSX/urbansound8k/data/._8544.wav
#   inflating: urbansound8k/data/7677.wav
#   inflating: __MACOSX/urbansound8k/data/._7677.wav
#   inflating: urbansound8k/data/792.wav
#   inflating: __MACOSX/urbansound8k/data/._792.wav
#   inflating: urbansound8k/data/1206.wav
#   inflating: __MACOSX/urbansound8k/data/._1206.wav
#   inflating: urbansound8k/data/1560.wav
#   inflating: __MACOSX/urbansound8k/data/._1560.wav
#   inflating: urbansound8k/data/7111.wav
#   inflating: __MACOSX/urbansound8k/data/._7111.wav
#   inflating: urbansound8k/data/4418.wav
#   inflating: __MACOSX/urbansound8k/data/._4418.wav
#   inflating: urbansound8k/data/5706.wav
#   inflating: __MACOSX/urbansound8k/data/._5706.wav
#   inflating: urbansound8k/data/3363.wav
#   inflating: __MACOSX/urbansound8k/data/._3363.wav
#   inflating: urbansound8k/data/5712.wav
#   inflating: __MACOSX/urbansound8k/data/._5712.wav
#   inflating: urbansound8k/data/1574.wav
#   inflating: __MACOSX/urbansound8k/data/._1574.wav
#   inflating: urbansound8k/data/8236.wav
#   inflating: __MACOSX/urbansound8k/data/._8236.wav
#   inflating: urbansound8k/data/7105.wav
#   inflating: __MACOSX/urbansound8k/data/._7105.wav
#   inflating: urbansound8k/data/5074.wav
#   inflating: __MACOSX/urbansound8k/data/._5074.wav
#   inflating: urbansound8k/data/8578.wav
#   inflating: __MACOSX/urbansound8k/data/._8578.wav
#   inflating: urbansound8k/data/7893.wav
#   inflating: __MACOSX/urbansound8k/data/._7893.wav
#   inflating: urbansound8k/data/6555.wav
#   inflating: __MACOSX/urbansound8k/data/._6555.wav
#   inflating: urbansound8k/data/2733.wav
#   inflating: __MACOSX/urbansound8k/data/._2733.wav
#   inflating: urbansound8k/data/4424.wav
#   inflating: __MACOSX/urbansound8k/data/._4424.wav
#   inflating: urbansound8k/data/2055.wav
#   inflating: __MACOSX/urbansound8k/data/._2055.wav
#   inflating: urbansound8k/data/6227.wav
#   inflating: __MACOSX/urbansound8k/data/._6227.wav
#   inflating: urbansound8k/data/1548.wav
#   inflating: __MACOSX/urbansound8k/data/._1548.wav
#   inflating: urbansound8k/data/4430.wav
#   inflating: __MACOSX/urbansound8k/data/._4430.wav
#   inflating: urbansound8k/data/3439.wav
#   inflating: __MACOSX/urbansound8k/data/._3439.wav
#   inflating: urbansound8k/data/4356.wav
#   inflating: __MACOSX/urbansound8k/data/._4356.wav
#   inflating: urbansound8k/data/235.wav
#   inflating: __MACOSX/urbansound8k/data/._235.wav
#   inflating: urbansound8k/data/4801.wav
#   inflating: __MACOSX/urbansound8k/data/._4801.wav
#   inflating: urbansound8k/data/3808.wav
#   inflating: __MACOSX/urbansound8k/data/._3808.wav
#   inflating: urbansound8k/data/6970.wav
#   inflating: __MACOSX/urbansound8k/data/._6970.wav
#   inflating: urbansound8k/data/547.wav
#   inflating: __MACOSX/urbansound8k/data/._547.wav
#   inflating: urbansound8k/data/221.wav
#   inflating: __MACOSX/urbansound8k/data/._221.wav
#   inflating: urbansound8k/data/1945.wav
#   inflating: __MACOSX/urbansound8k/data/._1945.wav
#   inflating: urbansound8k/data/3834.wav
#   inflating: __MACOSX/urbansound8k/data/._3834.wav
#   inflating: urbansound8k/data/4183.wav
#   inflating: __MACOSX/urbansound8k/data/._4183.wav
#   inflating: urbansound8k/data/5289.wav
#   inflating: __MACOSX/urbansound8k/data/._5289.wav
#   inflating: urbansound8k/data/3820.wav
#   inflating: __MACOSX/urbansound8k/data/._3820.wav
#   inflating: urbansound8k/data/4197.wav
#   inflating: __MACOSX/urbansound8k/data/._4197.wav
#   inflating: urbansound8k/data/6958.wav
#   inflating: __MACOSX/urbansound8k/data/._6958.wav
#   inflating: urbansound8k/data/1789.wav
#   inflating: __MACOSX/urbansound8k/data/._1789.wav
#   inflating: urbansound8k/data/4829.wav
#   inflating: __MACOSX/urbansound8k/data/._4829.wav
#   inflating: urbansound8k/data/5504.wav
#   inflating: __MACOSX/urbansound8k/data/._5504.wav
#   inflating: urbansound8k/data/7313.wav
#   inflating: __MACOSX/urbansound8k/data/._7313.wav
#   inflating: urbansound8k/data/8020.wav
#   inflating: __MACOSX/urbansound8k/data/._8020.wav
#   inflating: urbansound8k/data/1004.wav
#   inflating: __MACOSX/urbansound8k/data/._1004.wav
#   inflating: urbansound8k/data/590.wav
#   inflating: __MACOSX/urbansound8k/data/._590.wav
#   inflating: urbansound8k/data/7475.wav
#   inflating: __MACOSX/urbansound8k/data/._7475.wav
#   inflating: urbansound8k/data/3613.wav
#   inflating: __MACOSX/urbansound8k/data/._3613.wav
#   inflating: urbansound8k/data/5262.wav
#   inflating: __MACOSX/urbansound8k/data/._5262.wav
#   inflating: urbansound8k/data/4168.wav
#   inflating: __MACOSX/urbansound8k/data/._4168.wav
#   inflating: urbansound8k/data/3607.wav
#   inflating: __MACOSX/urbansound8k/data/._3607.wav
#   inflating: urbansound8k/data/584.wav
#   inflating: __MACOSX/urbansound8k/data/._584.wav
#   inflating: urbansound8k/data/7307.wav
#   inflating: __MACOSX/urbansound8k/data/._7307.wav
#   inflating: urbansound8k/data/8034.wav
#   inflating: __MACOSX/urbansound8k/data/._8034.wav
#   inflating: urbansound8k/data/1776.wav
#   inflating: __MACOSX/urbansound8k/data/._1776.wav
#   inflating: urbansound8k/data/6019.wav
#   inflating: __MACOSX/urbansound8k/data/._6019.wav
#   inflating: urbansound8k/data/3161.wav
#   inflating: __MACOSX/urbansound8k/data/._3161.wav
#   inflating: urbansound8k/data/1986.wav
#   inflating: __MACOSX/urbansound8k/data/._1986.wav
#   inflating: urbansound8k/data/6031.wav
#   inflating: __MACOSX/urbansound8k/data/._6031.wav
#   inflating: urbansound8k/data/4140.wav
#   inflating: __MACOSX/urbansound8k/data/._4140.wav
#   inflating: urbansound8k/data/2531.wav
#   inflating: __MACOSX/urbansound8k/data/._2531.wav
#   inflating: urbansound8k/data/6757.wav
#   inflating: __MACOSX/urbansound8k/data/._6757.wav
#   inflating: urbansound8k/data/1038.wav
#   inflating: __MACOSX/urbansound8k/data/._1038.wav
#   inflating: urbansound8k/data/7449.wav
#   inflating: __MACOSX/urbansound8k/data/._7449.wav
#   inflating: urbansound8k/data/4632.wav
#   inflating: __MACOSX/urbansound8k/data/._4632.wav
#   inflating: urbansound8k/data/1992.wav
#   inflating: __MACOSX/urbansound8k/data/._1992.wav
#   inflating: urbansound8k/data/8008.wav
#   inflating: __MACOSX/urbansound8k/data/._8008.wav
#   inflating: urbansound8k/data/6025.wav
#   inflating: __MACOSX/urbansound8k/data/._6025.wav
#   inflating: urbansound8k/data/3165.wav
#   inflating: __MACOSX/urbansound8k/data/._3165.wav
#   inflating: urbansound8k/data/5514.wav
#   inflating: __MACOSX/urbansound8k/data/._5514.wav
#   inflating: urbansound8k/data/7465.wav
#   inflating: __MACOSX/urbansound8k/data/._7465.wav
#   inflating: urbansound8k/data/1014.wav
#   inflating: __MACOSX/urbansound8k/data/._1014.wav
#   inflating: urbansound8k/data/580.wav
#   inflating: __MACOSX/urbansound8k/data/._580.wav
#   inflating: urbansound8k/data/5272.wav
#   inflating: __MACOSX/urbansound8k/data/._5272.wav
#   inflating: urbansound8k/data/3603.wav
#   inflating: __MACOSX/urbansound8k/data/._3603.wav
#   inflating: urbansound8k/data/2509.wav
#   inflating: __MACOSX/urbansound8k/data/._2509.wav
#   inflating: urbansound8k/data/5266.wav
#   inflating: __MACOSX/urbansound8k/data/._5266.wav
#   inflating: urbansound8k/data/4178.wav
#   inflating: __MACOSX/urbansound8k/data/._4178.wav
#   inflating: urbansound8k/data/7471.wav
#   inflating: __MACOSX/urbansound8k/data/._7471.wav
#   inflating: urbansound8k/data/594.wav
#   inflating: __MACOSX/urbansound8k/data/._594.wav
#   inflating: urbansound8k/data/1000.wav
#   inflating: __MACOSX/urbansound8k/data/._1000.wav
#   inflating: urbansound8k/data/1766.wav
#   inflating: __MACOSX/urbansound8k/data/._1766.wav
#   inflating: urbansound8k/data/6009.wav
#   inflating: __MACOSX/urbansound8k/data/._6009.wav
#   inflating: urbansound8k/data/8024.wav
#   inflating: __MACOSX/urbansound8k/data/._8024.wav
#   inflating: urbansound8k/data/3171.wav
#   inflating: __MACOSX/urbansound8k/data/._3171.wav
#   inflating: urbansound8k/data/6021.wav
#   inflating: __MACOSX/urbansound8k/data/._6021.wav
#   inflating: urbansound8k/data/1996.wav
#   inflating: __MACOSX/urbansound8k/data/._1996.wav
#   inflating: urbansound8k/data/3159.wav
#   inflating: __MACOSX/urbansound8k/data/._3159.wav
#   inflating: urbansound8k/data/4636.wav
#   inflating: __MACOSX/urbansound8k/data/._4636.wav
#   inflating: urbansound8k/data/5528.wav
#   inflating: __MACOSX/urbansound8k/data/._5528.wav
#   inflating: urbansound8k/data/2247.wav
#   inflating: __MACOSX/urbansound8k/data/._2247.wav
#   inflating: urbansound8k/data/7459.wav
#   inflating: __MACOSX/urbansound8k/data/._7459.wav
#   inflating: urbansound8k/data/6747.wav
#   inflating: __MACOSX/urbansound8k/data/._6747.wav
#   inflating: urbansound8k/data/1028.wav
#   inflating: __MACOSX/urbansound8k/data/._1028.wav
#   inflating: urbansound8k/data/6753.wav
#   inflating: __MACOSX/urbansound8k/data/._6753.wav
#   inflating: urbansound8k/data/4622.wav
#   inflating: __MACOSX/urbansound8k/data/._4622.wav
#   inflating: urbansound8k/data/2253.wav
#   inflating: __MACOSX/urbansound8k/data/._2253.wav
#   inflating: urbansound8k/data/6035.wav
#   inflating: __MACOSX/urbansound8k/data/._6035.wav
#   inflating: urbansound8k/data/1982.wav
#   inflating: __MACOSX/urbansound8k/data/._1982.wav
#   inflating: urbansound8k/data/543.wav
#   inflating: __MACOSX/urbansound8k/data/._543.wav
#   inflating: urbansound8k/data/557.wav
#   inflating: __MACOSX/urbansound8k/data/._557.wav
#   inflating: urbansound8k/data/6974.wav
#   inflating: __MACOSX/urbansound8k/data/._6974.wav
#   inflating: urbansound8k/data/4805.wav
#   inflating: __MACOSX/urbansound8k/data/._4805.wav
#   inflating: urbansound8k/data/219.wav
#   inflating: __MACOSX/urbansound8k/data/._219.wav
#   inflating: urbansound8k/data/4193.wav
#   inflating: __MACOSX/urbansound8k/data/._4193.wav
#   inflating: urbansound8k/data/3830.wav
#   inflating: __MACOSX/urbansound8k/data/._3830.wav
#   inflating: urbansound8k/data/5299.wav
#   inflating: __MACOSX/urbansound8k/data/._5299.wav
#   inflating: urbansound8k/data/6790.wav
#   inflating: __MACOSX/urbansound8k/data/._6790.wav
#   inflating: urbansound8k/data/6948.wav
#   inflating: __MACOSX/urbansound8k/data/._6948.wav
#   inflating: urbansound8k/data/1941.wav
#   inflating: __MACOSX/urbansound8k/data/._1941.wav
#   inflating: urbansound8k/data/2290.wav
#   inflating: __MACOSX/urbansound8k/data/._2290.wav
#   inflating: urbansound8k/data/4839.wav
#   inflating: __MACOSX/urbansound8k/data/._4839.wav
#   inflating: urbansound8k/data/3401.wav
#   inflating: __MACOSX/urbansound8k/data/._3401.wav
#   inflating: urbansound8k/data/6579.wav
#   inflating: __MACOSX/urbansound8k/data/._6579.wav
#   inflating: urbansound8k/data/8232.wav
#   inflating: __MACOSX/urbansound8k/data/._8232.wav
#   inflating: urbansound8k/data/1570.wav
#   inflating: __MACOSX/urbansound8k/data/._1570.wav
#   inflating: urbansound8k/data/5716.wav
#   inflating: __MACOSX/urbansound8k/data/._5716.wav
#   inflating: urbansound8k/data/4408.wav
#   inflating: __MACOSX/urbansound8k/data/._4408.wav
#   inflating: urbansound8k/data/3367.wav
#   inflating: __MACOSX/urbansound8k/data/._3367.wav
#   inflating: urbansound8k/data/5702.wav
#   inflating: __MACOSX/urbansound8k/data/._5702.wav
#   inflating: urbansound8k/data/3373.wav
#   inflating: __MACOSX/urbansound8k/data/._3373.wav
#   inflating: urbansound8k/data/7115.wav
#   inflating: __MACOSX/urbansound8k/data/._7115.wav
#   inflating: urbansound8k/data/1564.wav
#   inflating: __MACOSX/urbansound8k/data/._1564.wav
#   inflating: urbansound8k/data/796.wav
#   inflating: __MACOSX/urbansound8k/data/._796.wav
#   inflating: urbansound8k/data/7673.wav
#   inflating: __MACOSX/urbansound8k/data/._7673.wav
#   inflating: urbansound8k/data/8540.wav
#   inflating: __MACOSX/urbansound8k/data/._8540.wav
#   inflating: urbansound8k/data/3415.wav
#   inflating: __MACOSX/urbansound8k/data/._3415.wav
#   inflating: urbansound8k/data/5064.wav
#   inflating: __MACOSX/urbansound8k/data/._5064.wav
#   inflating: urbansound8k/data/7883.wav
#   inflating: __MACOSX/urbansound8k/data/._7883.wav
#   inflating: urbansound8k/data/8568.wav
#   inflating: __MACOSX/urbansound8k/data/._8568.wav
#   inflating: urbansound8k/data/4352.wav
#   inflating: __MACOSX/urbansound8k/data/._4352.wav
#   inflating: urbansound8k/data/2723.wav
#   inflating: __MACOSX/urbansound8k/data/._2723.wav
#   inflating: urbansound8k/data/2045.wav
#   inflating: __MACOSX/urbansound8k/data/._2045.wav
#   inflating: urbansound8k/data/7129.wav
#   inflating: __MACOSX/urbansound8k/data/._7129.wav
#   inflating: urbansound8k/data/1558.wav
#   inflating: __MACOSX/urbansound8k/data/._1558.wav
#   inflating: urbansound8k/data/2051.wav
#   inflating: __MACOSX/urbansound8k/data/._2051.wav
#   inflating: urbansound8k/data/4420.wav
#   inflating: __MACOSX/urbansound8k/data/._4420.wav
#   inflating: urbansound8k/data/3429.wav
#   inflating: __MACOSX/urbansound8k/data/._3429.wav
#   inflating: urbansound8k/data/4346.wav
#   inflating: __MACOSX/urbansound8k/data/._4346.wav
#   inflating: urbansound8k/data/5058.wav
#   inflating: __MACOSX/urbansound8k/data/._5058.wav
#   inflating: urbansound8k/data/7897.wav
#   inflating: __MACOSX/urbansound8k/data/._7897.wav
#   inflating: urbansound8k/data/6551.wav
#   inflating: __MACOSX/urbansound8k/data/._6551.wav
#   inflating: urbansound8k/data/972.wav
#   inflating: __MACOSX/urbansound8k/data/._972.wav
#   inflating: urbansound8k/data/8597.wav
#   inflating: __MACOSX/urbansound8k/data/._8597.wav
#   inflating: urbansound8k/data/2910.wav
#   inflating: __MACOSX/urbansound8k/data/._2910.wav
#   inflating: urbansound8k/data/7868.wav
#   inflating: __MACOSX/urbansound8k/data/._7868.wav
#   inflating: urbansound8k/data/755.wav
#   inflating: __MACOSX/urbansound8k/data/._755.wav
#   inflating: urbansound8k/data/3398.wav
#   inflating: __MACOSX/urbansound8k/data/._3398.wav
#   inflating: urbansound8k/data/5925.wav
#   inflating: __MACOSX/urbansound8k/data/._5925.wav
#   inflating: urbansound8k/data/7854.wav
#   inflating: __MACOSX/urbansound8k/data/._7854.wav
#   inflating: urbansound8k/data/6592.wav
#   inflating: __MACOSX/urbansound8k/data/._6592.wav
#   inflating: urbansound8k/data/7713.wav
#   inflating: __MACOSX/urbansound8k/data/._7713.wav
#   inflating: urbansound8k/data/8420.wav
#   inflating: __MACOSX/urbansound8k/data/._8420.wav
#   inflating: urbansound8k/data/1404.wav
#   inflating: __MACOSX/urbansound8k/data/._1404.wav
#   inflating: urbansound8k/data/7075.wav
#   inflating: __MACOSX/urbansound8k/data/._7075.wav
#   inflating: urbansound8k/data/8346.wav
#   inflating: __MACOSX/urbansound8k/data/._8346.wav
#   inflating: urbansound8k/data/3213.wav
#   inflating: __MACOSX/urbansound8k/data/._3213.wav
#   inflating: urbansound8k/data/5662.wav
#   inflating: __MACOSX/urbansound8k/data/._5662.wav
#   inflating: urbansound8k/data/3207.wav
#   inflating: __MACOSX/urbansound8k/data/._3207.wav
#   inflating: urbansound8k/data/4568.wav
#   inflating: __MACOSX/urbansound8k/data/._4568.wav
#   inflating: urbansound8k/data/5676.wav
#   inflating: __MACOSX/urbansound8k/data/._5676.wav
#   inflating: urbansound8k/data/184.wav
#   inflating: __MACOSX/urbansound8k/data/._184.wav
#   inflating: urbansound8k/data/7061.wav
#   inflating: __MACOSX/urbansound8k/data/._7061.wav
#   inflating: urbansound8k/data/8352.wav
#   inflating: __MACOSX/urbansound8k/data/._8352.wav
#   inflating: urbansound8k/data/7707.wav
#   inflating: __MACOSX/urbansound8k/data/._7707.wav
#   inflating: urbansound8k/data/8434.wav
#   inflating: __MACOSX/urbansound8k/data/._8434.wav
#   inflating: urbansound8k/data/5110.wav
#   inflating: __MACOSX/urbansound8k/data/._5110.wav
#   inflating: urbansound8k/data/3561.wav
#   inflating: __MACOSX/urbansound8k/data/._3561.wav
#   inflating: urbansound8k/data/812.wav
#   inflating: __MACOSX/urbansound8k/data/._812.wav
#   inflating: urbansound8k/data/6431.wav
#   inflating: __MACOSX/urbansound8k/data/._6431.wav
#   inflating: urbansound8k/data/52.wav
#   inflating: __MACOSX/urbansound8k/data/._52.wav
#   inflating: urbansound8k/data/2657.wav
#   inflating: __MACOSX/urbansound8k/data/._2657.wav
#   inflating: urbansound8k/data/5138.wav
#   inflating: __MACOSX/urbansound8k/data/._5138.wav
#   inflating: urbansound8k/data/4226.wav
#   inflating: __MACOSX/urbansound8k/data/._4226.wav
#   inflating: urbansound8k/data/3549.wav
#   inflating: __MACOSX/urbansound8k/data/._3549.wav
#   inflating: urbansound8k/data/5886.wav
#   inflating: __MACOSX/urbansound8k/data/._5886.wav
#   inflating: urbansound8k/data/0.wav
#   inflating: __MACOSX/urbansound8k/data/._0.wav
#   inflating: urbansound8k/data/4540.wav
#   inflating: __MACOSX/urbansound8k/data/._4540.wav
#   inflating: urbansound8k/data/6357.wav
#   inflating: __MACOSX/urbansound8k/data/._6357.wav
#   inflating: urbansound8k/data/7049.wav
#   inflating: __MACOSX/urbansound8k/data/._7049.wav
# ...
#   inflating: __MACOSX/urbansound8k/data/._324.wav
#   inflating: urbansound8k/data/6134.wav
#   inflating: __MACOSX/urbansound8k/data/._6134.wav
#   inflating: urbansound8k/data/1883.wav
#   inflating: __MACOSX/urbansound8k/data/._1883.wav
#   inflating: urbansound8k/data/8119.wav
#   inflating: __MACOSX/urbansound8k/data/._8119.wav
#   inflating: urbansound8k/data/4723.wav
#   inflating: __MACOSX/urbansound8k/data/._4723.wav
#   inflating: urbansound8k/data/4045.wav
#   inflating: __MACOSX/urbansound8k/data/._4045.wav
#   inflating: urbansound8k/data/6652.wav
#   inflating: __MACOSX/urbansound8k/data/._6652.wav
#   inflating: urbansound8k/data/7558.wav
#   inflating: __MACOSX/urbansound8k/data/._7558.wav
#   inflating: urbansound8k/data/1129.wav
#   inflating: __MACOSX/urbansound8k/data/._1129.wav
#   inflating: urbansound8k/data/2420.wav
#   inflating: __MACOSX/urbansound8k/data/._2420.wav
#   inflating: urbansound8k/data/4737.wav
#   inflating: __MACOSX/urbansound8k/data/._4737.wav
#   inflating: urbansound8k/data/5429.wav
#   inflating: __MACOSX/urbansound8k/data/._5429.wav
#   inflating: urbansound8k/data/6120.wav
#   inflating: __MACOSX/urbansound8k/data/._6120.wav
#   inflating: urbansound8k/data/1897.wav
#   inflating: __MACOSX/urbansound8k/data/._1897.wav
#   inflating: urbansound8k/data/3070.wav
#   inflating: __MACOSX/urbansound8k/data/._3070.wav
#   inflating: urbansound8k/data/1667.wav
#   inflating: __MACOSX/urbansound8k/data/._1667.wav
#   inflating: urbansound8k/data/6108.wav
#   inflating: __MACOSX/urbansound8k/data/._6108.wav
#   inflating: urbansound8k/data/7216.wav
#   inflating: __MACOSX/urbansound8k/data/._7216.wav
#   inflating: urbansound8k/data/8125.wav
#   inflating: __MACOSX/urbansound8k/data/._8125.wav
#   inflating: urbansound8k/data/7570.wav
#   inflating: __MACOSX/urbansound8k/data/._7570.wav
#   inflating: urbansound8k/data/8643.wav
#   inflating: __MACOSX/urbansound8k/data/._8643.wav
#   inflating: urbansound8k/data/495.wav
#   inflating: __MACOSX/urbansound8k/data/._495.wav
#   inflating: urbansound8k/data/2408.wav
#   inflating: __MACOSX/urbansound8k/data/._2408.wav
#   inflating: urbansound8k/data/5373.wav
#   inflating: __MACOSX/urbansound8k/data/._5373.wav
#   inflating: urbansound8k/data/3702.wav
#   inflating: __MACOSX/urbansound8k/data/._3702.wav
#   inflating: urbansound8k/data/8657.wav
#   inflating: __MACOSX/urbansound8k/data/._8657.wav
#   inflating: urbansound8k/data/1115.wav
#   inflating: __MACOSX/urbansound8k/data/._1115.wav
#   inflating: urbansound8k/data/1673.wav
#   inflating: __MACOSX/urbansound8k/data/._1673.wav
#   inflating: urbansound8k/data/7202.wav
#   inflating: __MACOSX/urbansound8k/data/._7202.wav
#   inflating: urbansound8k/data/8131.wav
#   inflating: __MACOSX/urbansound8k/data/._8131.wav
#   inflating: urbansound8k/data/5415.wav
#   inflating: __MACOSX/urbansound8k/data/._5415.wav
#   inflating: urbansound8k/data/7955.wav
#   inflating: __MACOSX/urbansound8k/data/._7955.wav
#   inflating: urbansound8k/data/6493.wav
#   inflating: __MACOSX/urbansound8k/data/._6493.wav
#   inflating: urbansound8k/data/5824.wav
#   inflating: __MACOSX/urbansound8k/data/._5824.wav
#   inflating: urbansound8k/data/2193.wav
#   inflating: __MACOSX/urbansound8k/data/._2193.wav
#   inflating: urbansound8k/data/3299.wav
#   inflating: __MACOSX/urbansound8k/data/._3299.wav
#   inflating: urbansound8k/data/7941.wav
#   inflating: __MACOSX/urbansound8k/data/._7941.wav
#   inflating: urbansound8k/data/6487.wav
#   inflating: __MACOSX/urbansound8k/data/._6487.wav
#   inflating: urbansound8k/data/4290.wav
#   inflating: __MACOSX/urbansound8k/data/._4290.wav
#   inflating: urbansound8k/data/8482.wav
#   inflating: __MACOSX/urbansound8k/data/._8482.wav
#   inflating: urbansound8k/data/654.wav
#   inflating: __MACOSX/urbansound8k/data/._654.wav
#   inflating: urbansound8k/data/7969.wav
#   inflating: __MACOSX/urbansound8k/data/._7969.wav
#   inflating: urbansound8k/data/2811.wav
#   inflating: __MACOSX/urbansound8k/data/._2811.wav
#   inflating: urbansound8k/data/5818.wav
#   inflating: __MACOSX/urbansound8k/data/._5818.wav
#   inflating: urbansound8k/data/132.wav
#   inflating: __MACOSX/urbansound8k/data/._132.wav
#   inflating: urbansound8k/data/2805.wav
#   inflating: __MACOSX/urbansound8k/data/._2805.wav
#   inflating: urbansound8k/data/8496.wav
#   inflating: __MACOSX/urbansound8k/data/._8496.wav
#   inflating: urbansound8k/data/898.wav
#   inflating: __MACOSX/urbansound8k/data/._898.wav
#   inflating: urbansound8k/data/7996.wav
#   inflating: __MACOSX/urbansound8k/data/._7996.wav
#   inflating: urbansound8k/data/6450.wav
#   inflating: __MACOSX/urbansound8k/data/._6450.wav
#   inflating: urbansound8k/data/33.wav
#   inflating: __MACOSX/urbansound8k/data/._33.wav
#   inflating: urbansound8k/data/3528.wav
#   inflating: __MACOSX/urbansound8k/data/._3528.wav
#   inflating: urbansound8k/data/4247.wav
#   inflating: __MACOSX/urbansound8k/data/._4247.wav
#   inflating: urbansound8k/data/5159.wav
#   inflating: __MACOSX/urbansound8k/data/._5159.wav
#   inflating: urbansound8k/data/2636.wav
#   inflating: __MACOSX/urbansound8k/data/._2636.wav
#   inflating: urbansound8k/data/2150.wav
#   inflating: __MACOSX/urbansound8k/data/._2150.wav
#   inflating: urbansound8k/data/4521.wav
#   inflating: __MACOSX/urbansound8k/data/._4521.wav
#   inflating: urbansound8k/data/7028.wav
#   inflating: __MACOSX/urbansound8k/data/._7028.wav
#   inflating: urbansound8k/data/6336.wav
#   inflating: __MACOSX/urbansound8k/data/._6336.wav
#   inflating: urbansound8k/data/1459.wav
#   inflating: __MACOSX/urbansound8k/data/._1459.wav
#   inflating: urbansound8k/data/6322.wav
#   inflating: __MACOSX/urbansound8k/data/._6322.wav
#   inflating: urbansound8k/data/2144.wav
#   inflating: __MACOSX/urbansound8k/data/._2144.wav
#   inflating: urbansound8k/data/4535.wav
#   inflating: __MACOSX/urbansound8k/data/._4535.wav
#   inflating: urbansound8k/data/4253.wav
#   inflating: __MACOSX/urbansound8k/data/._4253.wav
#   inflating: urbansound8k/data/7982.wav
#   inflating: __MACOSX/urbansound8k/data/._7982.wav
#   inflating: urbansound8k/data/27.wav
#   inflating: __MACOSX/urbansound8k/data/._27.wav
#   inflating: urbansound8k/data/867.wav
#   inflating: __MACOSX/urbansound8k/data/._867.wav
#   inflating: urbansound8k/data/8469.wav
#   inflating: __MACOSX/urbansound8k/data/._8469.wav
#   inflating: urbansound8k/data/3514.wav
#   inflating: __MACOSX/urbansound8k/data/._3514.wav
#   inflating: urbansound8k/data/5165.wav
#   inflating: __MACOSX/urbansound8k/data/._5165.wav
#   inflating: urbansound8k/data/1303.wav
#   inflating: __MACOSX/urbansound8k/data/._1303.wav
#   inflating: urbansound8k/data/697.wav
#   inflating: __MACOSX/urbansound8k/data/._697.wav
#   inflating: urbansound8k/data/8441.wav
#   inflating: __MACOSX/urbansound8k/data/._8441.wav
#   inflating: urbansound8k/data/8327.wav
#   inflating: __MACOSX/urbansound8k/data/._8327.wav
#   inflating: urbansound8k/data/7014.wav
#   inflating: __MACOSX/urbansound8k/data/._7014.wav
#   inflating: urbansound8k/data/3272.wav
#   inflating: __MACOSX/urbansound8k/data/._3272.wav
#   inflating: urbansound8k/data/4509.wav
#   inflating: __MACOSX/urbansound8k/data/._4509.wav
#   inflating: urbansound8k/data/3266.wav
#   inflating: __MACOSX/urbansound8k/data/._3266.wav
#   inflating: urbansound8k/data/8333.wav
#   inflating: __MACOSX/urbansound8k/data/._8333.wav
#   inflating: urbansound8k/data/7000.wav
#   inflating: __MACOSX/urbansound8k/data/._7000.wav
#   inflating: urbansound8k/data/1471.wav
#   inflating: __MACOSX/urbansound8k/data/._1471.wav
#   inflating: urbansound8k/data/683.wav
#   inflating: __MACOSX/urbansound8k/data/._683.wav
#   inflating: urbansound8k/data/1317.wav
#   inflating: __MACOSX/urbansound8k/data/._1317.wav
#   inflating: urbansound8k/data/6478.wav
#   inflating: __MACOSX/urbansound8k/data/._6478.wav
#   inflating: urbansound8k/data/7766.wav
#   inflating: __MACOSX/urbansound8k/data/._7766.wav
#   inflating: urbansound8k/data/5171.wav
#   inflating: __MACOSX/urbansound8k/data/._5171.wav
#   inflating: urbansound8k/data/2959.wav
#   inflating: __MACOSX/urbansound8k/data/._2959.wav
#   inflating: urbansound8k/data/2781.wav
#   inflating: __MACOSX/urbansound8k/data/._2781.wav
#   inflating: urbansound8k/data/7821.wav
#   inflating: __MACOSX/urbansound8k/data/._7821.wav
#   inflating: urbansound8k/data/5788.wav
#   inflating: __MACOSX/urbansound8k/data/._5788.wav
#   inflating: urbansound8k/data/5950.wav
#   inflating: __MACOSX/urbansound8k/data/._5950.wav
#   inflating: urbansound8k/data/5944.wav
#   inflating: __MACOSX/urbansound8k/data/._5944.wav
#   inflating: urbansound8k/data/4482.wav
#   inflating: __MACOSX/urbansound8k/data/._4482.wav
#   inflating: urbansound8k/data/6295.wav
#   inflating: __MACOSX/urbansound8k/data/._6295.wav
#   inflating: urbansound8k/data/7835.wav
#   inflating: __MACOSX/urbansound8k/data/._7835.wav
#   inflating: urbansound8k/data/2795.wav
#   inflating: __MACOSX/urbansound8k/data/._2795.wav
#   inflating: urbansound8k/data/720.wav
#   inflating: __MACOSX/urbansound8k/data/._720.wav
#   inflating: urbansound8k/data/2971.wav
#   inflating: __MACOSX/urbansound8k/data/._2971.wav
#   inflating: urbansound8k/data/734.wav
#   inflating: __MACOSX/urbansound8k/data/._734.wav
#   inflating: urbansound8k/data/907.wav
#   inflating: __MACOSX/urbansound8k/data/._907.wav
#   inflating: urbansound8k/data/6524.wav
#   inflating: __MACOSX/urbansound8k/data/._6524.wav
#   inflating: urbansound8k/data/4333.wav
#   inflating: __MACOSX/urbansound8k/data/._4333.wav
#   inflating: urbansound8k/data/6256.wav
#   inflating: __MACOSX/urbansound8k/data/._6256.wav
#   inflating: urbansound8k/data/7148.wav
#   inflating: __MACOSX/urbansound8k/data/._7148.wav
#   inflating: urbansound8k/data/2756.wav
#   inflating: __MACOSX/urbansound8k/data/._2756.wav
#   inflating: urbansound8k/data/4327.wav
#   inflating: __MACOSX/urbansound8k/data/._4327.wav
#   inflating: urbansound8k/data/913.wav
#   inflating: __MACOSX/urbansound8k/data/._913.wav
#   inflating: urbansound8k/data/6530.wav
#   inflating: __MACOSX/urbansound8k/data/._6530.wav
#   inflating: urbansound8k/data/5011.wav
#   inflating: __MACOSX/urbansound8k/data/._5011.wav
#   inflating: urbansound8k/data/8535.wav
#   inflating: __MACOSX/urbansound8k/data/._8535.wav
#   inflating: urbansound8k/data/6518.wav
#   inflating: __MACOSX/urbansound8k/data/._6518.wav
#   inflating: urbansound8k/data/1277.wav
#   inflating: __MACOSX/urbansound8k/data/._1277.wav
#   inflating: urbansound8k/data/1511.wav
#   inflating: __MACOSX/urbansound8k/data/._1511.wav
#   inflating: urbansound8k/data/8253.wav
#   inflating: __MACOSX/urbansound8k/data/._8253.wav
#   inflating: urbansound8k/data/3306.wav
#   inflating: __MACOSX/urbansound8k/data/._3306.wav
#   inflating: urbansound8k/data/2018.wav
#   inflating: __MACOSX/urbansound8k/data/._2018.wav
#   inflating: urbansound8k/data/5763.wav
#   inflating: __MACOSX/urbansound8k/data/._5763.wav
#   inflating: urbansound8k/data/8247.wav
#   inflating: __MACOSX/urbansound8k/data/._8247.wav
#   inflating: urbansound8k/data/7174.wav
#   inflating: __MACOSX/urbansound8k/data/._7174.wav
#   inflating: urbansound8k/data/7612.wav
#   inflating: __MACOSX/urbansound8k/data/._7612.wav
#   inflating: urbansound8k/data/5005.wav
#   inflating: __MACOSX/urbansound8k/data/._5005.wav
#   inflating: urbansound8k/data/3474.wav
#   inflating: __MACOSX/urbansound8k/data/._3474.wav
#   inflating: urbansound8k/data/6083.wav
#   inflating: __MACOSX/urbansound8k/data/._6083.wav
#   inflating: urbansound8k/data/278.wav
#   inflating: __MACOSX/urbansound8k/data/._278.wav
#   inflating: urbansound8k/data/3851.wav
#   inflating: __MACOSX/urbansound8k/data/._3851.wav
#   inflating: urbansound8k/data/2597.wav
#   inflating: __MACOSX/urbansound8k/data/._2597.wav
#   inflating: urbansound8k/data/3689.wav
#   inflating: __MACOSX/urbansound8k/data/._3689.wav
#   inflating: urbansound8k/data/6929.wav
#   inflating: __MACOSX/urbansound8k/data/._6929.wav
#   inflating: urbansound8k/data/7389.wav
#   inflating: __MACOSX/urbansound8k/data/._7389.wav
#   inflating: urbansound8k/data/4680.wav
#   inflating: __MACOSX/urbansound8k/data/._4680.wav
#   inflating: urbansound8k/data/4858.wav
#   inflating: __MACOSX/urbansound8k/data/._4858.wav
#   inflating: urbansound8k/data/1908.wav
#   inflating: __MACOSX/urbansound8k/data/._1908.wav
#   inflating: urbansound8k/data/8092.wav
#   inflating: __MACOSX/urbansound8k/data/._8092.wav
#   inflating: urbansound8k/data/4870.wav
#   inflating: __MACOSX/urbansound8k/data/._4870.wav
#   inflating: urbansound8k/data/3879.wav
#   inflating: __MACOSX/urbansound8k/data/._3879.wav
#   inflating: urbansound8k/data/6901.wav
#   inflating: __MACOSX/urbansound8k/data/._6901.wav
#   inflating: urbansound8k/data/522.wav
#   inflating: __MACOSX/urbansound8k/data/._522.wav
#   inflating: urbansound8k/data/6915.wav
#   inflating: __MACOSX/urbansound8k/data/._6915.wav
#   inflating: urbansound8k/data/4864.wav
#   inflating: __MACOSX/urbansound8k/data/._4864.wav
#   inflating: urbansound8k/data/250.wav
#   inflating: __MACOSX/urbansound8k/data/._250.wav
#   inflating: urbansound8k/data/8086.wav
#   inflating: __MACOSX/urbansound8k/data/._8086.wav
#   inflating: urbansound8k/data/6040.wav
#   inflating: __MACOSX/urbansound8k/data/._6040.wav
#   inflating: urbansound8k/data/2226.wav
#   inflating: __MACOSX/urbansound8k/data/._2226.wav
#   inflating: urbansound8k/data/4657.wav
#   inflating: __MACOSX/urbansound8k/data/._4657.wav
#   inflating: urbansound8k/data/3138.wav
#   inflating: __MACOSX/urbansound8k/data/._3138.wav
#   inflating: urbansound8k/data/4131.wav
#   inflating: __MACOSX/urbansound8k/data/._4131.wav
#   inflating: urbansound8k/data/3886.wav
#   inflating: __MACOSX/urbansound8k/data/._3886.wav
#   inflating: urbansound8k/data/1049.wav
#   inflating: __MACOSX/urbansound8k/data/._1049.wav
#   inflating: urbansound8k/data/6726.wav
#   inflating: __MACOSX/urbansound8k/data/._6726.wav
#   inflating: urbansound8k/data/6732.wav
#   inflating: __MACOSX/urbansound8k/data/._6732.wav
#   inflating: urbansound8k/data/4125.wav
#   inflating: __MACOSX/urbansound8k/data/._4125.wav
#   inflating: urbansound8k/data/4643.wav
#   inflating: __MACOSX/urbansound8k/data/._4643.wav
#   inflating: urbansound8k/data/8079.wav
#   inflating: __MACOSX/urbansound8k/data/._8079.wav
#   inflating: urbansound8k/data/6054.wav
#   inflating: __MACOSX/urbansound8k/data/._6054.wav
#   inflating: urbansound8k/data/3104.wav
#   inflating: __MACOSX/urbansound8k/data/._3104.wav
#   inflating: urbansound8k/data/7362.wav
#   inflating: __MACOSX/urbansound8k/data/._7362.wav
#   inflating: urbansound8k/data/1713.wav
#   inflating: __MACOSX/urbansound8k/data/._1713.wav
#   inflating: urbansound8k/data/7404.wav
#   inflating: __MACOSX/urbansound8k/data/._7404.wav
#   inflating: urbansound8k/data/3662.wav
#   inflating: __MACOSX/urbansound8k/data/._3662.wav
#   inflating: urbansound8k/data/3676.wav
#   inflating: __MACOSX/urbansound8k/data/._3676.wav
#   inflating: urbansound8k/data/4119.wav
#   inflating: __MACOSX/urbansound8k/data/._4119.wav
#   inflating: urbansound8k/data/2568.wav
#   inflating: __MACOSX/urbansound8k/data/._2568.wav
#   inflating: urbansound8k/data/1061.wav
#   inflating: __MACOSX/urbansound8k/data/._1061.wav
#   inflating: urbansound8k/data/7410.wav
#   inflating: __MACOSX/urbansound8k/data/._7410.wav
#   inflating: urbansound8k/data/8723.wav
#   inflating: __MACOSX/urbansound8k/data/._8723.wav
#   inflating: urbansound8k/data/7376.wav
#   inflating: __MACOSX/urbansound8k/data/._7376.wav
#   inflating: urbansound8k/data/6068.wav
#   inflating: __MACOSX/urbansound8k/data/._6068.wav
#   inflating: urbansound8k/data/5561.wav
#   inflating: __MACOSX/urbansound8k/data/._5561.wav
#   inflating: urbansound8k/data/3110.wav
#   inflating: __MACOSX/urbansound8k/data/._3110.wav

# %%
# классы данных
classes = ['air_conditioner', 'car_horn', 'children_playing', 'dog_bark',
           'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 
           'siren', 'street_music']

# %%
w, s = torchaudio.load('./data/urbansound8k/data/1.wav')
print(w.shape, w.squeeze().shape)
# Out:
# torch.Size([1, 192000]) torch.Size([192000])

# %%
len(w.squeeze())
# Out:
# 192000

# %%
import os

import pandas as pd
import numpy as np


class AudioDataset(Dataset):
    def __init__(self, path_to_csv: str, 
                 path_to_folder: str, 
                 pad_size: int=384000,
                 sr: int = 44100):
        self.csv: pd.DataFrame = pd.read_csv(path_to_csv)[['ID', 'Class']]
        self.path_to_folder = path_to_folder
        self.pad_size = pad_size

        self.sr = sr

        self.class_to_idx = {classes[i]: i for i in range(10)}

    def __getitem__(self, index: int):
        output = self.csv.iloc[index]
        id = output['ID']
        end = '/' + str(id) + '.wav'
        path = str(self.path_to_folder) + end

        wav, sr = torchaudio.load(path)
        if sr != self.sr:
            resampler = torchaudio.transforms.Resample(sr, self.sr)
            wav = resampler(wav)
        
        wav = wav.squeeze() # уберем лишнюю размерность (из [1, n] -> [n])

        if len(wav) <= self.pad_size:
          num = self.pad_size - len(wav)
          #print(num)
          wav1 = torch.zeros(num, dtype=torch.float32)
          wav1 = torch.cat((wav, wav1))
        else:
          wav1 = wav
        
        y = self.class_to_idx[output['Class']]

        instance = {
            'len': len(wav),
            'x': wav1,
            'y': y
        }

        return instance

    def __len__(self):
        return self.csv.shape[0]

# %%
# создадим датасеты
train_dataset = AudioDataset('./data/urbansound8k/train_part.csv', './data/urbansound8k/data')
val_dataset = AudioDataset('./data/urbansound8k/val_part.csv', './data/urbansound8k/data')

# %%
# проверим размеры датасетов
assert len(train_dataset) == 4500
assert len(val_dataset) == 935

# %%
# проверим возращаемые значения __getitem__
item = train_dataset.__getitem__(0)

assert item['x'].shape == (384000, )
assert item['y'] == 0
assert item['len'] == 176400

# %% [markdown]
# ![bark.jpg](data:image/jpeg;base64,...)

# %%
# нарисуем и проиграем лай собачки
item = train_dataset.__getitem__(33)
plt.figure(figsize=(16, 8))
plt.plot(item['x'])

display.Audio(item['x'], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# создадим даталоадеры
train_dataloader = DataLoader(train_dataset, 32, shuffle=True,
                              pin_memory=True, drop_last=True)
val_dataloader = DataLoader(val_dataset, 32,
                            pin_memory=True)

# %% [markdown]
# ## Задание 2. Рекуррентная сеть для классификации аудиозаписей по сырому сигналу (2 балла)
#
# По своей сути аудиозапись является ни чем иным, как временным рядом - замеры микрофона делаются через равные промежутки времени и хранятся в виде последовательности.
#
# Как известно, рекуррентные сети отлично подходят для работы с различными последовательностями, в том числе и с временными рядами.
#
# Обучим простую реккурентную сеть для классификации аудиозаписей.
#
# 1. Разбейте аудизаписить на окошки размером `1024` с шагом `256`. Для этих целей отлично подойдет метод `torch.Tensor.unfold`.
# 1. Применим к каждому получившемуся окну аудиосигнала полносвязную сеть с активациями `ReLU` и  внутренними размерностям `(1024 -> 256 -> 64 -> 16)`.
# 2. По получившимся последовательностям пройдемся двунаправленой (`bidirectional=True`) LSTM с двумя слоями (`layers=2`).
# 3. Склеим c помощью `torch.cat` последние `hidden_state` для каждого слоя и применим к ним полносвязную сеть `(2 * hidden_size * num_layers -> 256 -> 10)` с активацией `ReLU`.
#
# ![title](https://github.com/aromana33/hw5_dl_2021/blob/main/images/rnn_raw.png?raw=1)
#
# *Совет*: для убыстрения обучения имеет смысл в полносвязные сети добавить `BatchNorm`.

# %%
class RecurrentRawAudioClassifier(nn.Module):
  def __init__(self, 
               num_classes=10,
               window_length=1024,
               hop_length=256,
               hidden=256,
               num_layers=2):
    super().__init__()

    self.window_length = window_length
    self.hop_length = hop_length

    ### YOUR CODE IS HERE ######
    self.first_mlp = nn.Sequential(        
        nn.Linear(1024, 256),
        nn.ReLU(),
        nn.Linear(256, 64),
        nn.ReLU(),
        nn.Linear(64, 16))

    self.rnn = nn.LSTM(input_size=16, 
                       hidden_size=hidden, 
                       num_layers=2, 
                       bidirectional=True)

    self.final_mlp = nn.Sequential(
        nn.Linear(1024, 256),
        nn.BatchNorm1d(256), # c батчнормом получается побыстрей
        nn.ReLU(),
        nn.Linear(256, 10)
    ) 

  def forward(self, x, lens):
    # разбейте сигнал на окна 
    # batch_windows.shape == (B, NUM WINDOWS, 1024)
    B = 1
    batch_windows = x.unfold(B, 1024, 256)    #your code here


    # примените к каждому окну полносвязную сеть
    # batch_windows_feautures.shape == (B, NUM WINDOWS, 16)
    batch_windows_feautures = self.first_mlp(batch_windows)

    # примените к получившемся последовательностям LSTM и возьмите hidden state
    batch_windows_feautures_t = batch_windows_feautures.transpose(1, 0)
    lstm, (h,f) = self.rnn(batch_windows_feautures_t)

    # склейте hidden_state по слоям
    # hidden_flattened.shape = (B, 2 * hidden_size * num_layers)

    hidden_flattened = torch.cat((h[0], h[1], h[-2], h[-1]), dim=1)

    # примените полносвязную сеть и получим логиты классов
    return self.final_mlp(hidden_flattened)

# %% [markdown]
# Обучим получившуюся модель.

# %%
from IPython.display import clear_output

def train_audio_clfr(model, optimizer, train_dataloader, sr,
                     criterion=torch.nn.CrossEntropyLoss(),
                     data_transform=None, 
                     augmentation=None,
                     num_epochs=10, device='cuda:0',
                     verbose_num_iters=10):
  model.train()
  iter_i = 0

  train_losses = []
  train_accuracies = []

  for epoch in range(num_epochs):  
    for batch in train_dataloader:
        x = batch['x'].to(device)
        y = batch['y'].to(device)
        lens = batch['len'].to(device)
        
        # применяем преобразование входных данных
        if data_transform:
          x, lens = data_transform(x,
                                   lens, 
                                   device=device, 
                                   sr=sr)

        # примеменяем к логмелспектрограмме аугментацию
        if augmentation:
          x, lens = augmentation(x, lens)

        # делаем предсказания
        probs = model(x, lens)

        # делаем шаг градиента
        optimizer.zero_grad()
        loss = criterion(probs, y)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        
        # считаем точность предсказания
        pred_cls = probs.argmax(dim=-1)
        train_accuracies.append((pred_cls == y).float().mean().item())
    
        iter_i += 1

        # раз в verbose_num_iters визуализируем наши лоссы и семплы
        if iter_i % verbose_num_iters == 0:
            clear_output(wait=True)

            print(f'Epoch {epoch}')

            plt.figure(figsize=(10, 5))
                
            plt.subplot(1, 2, 1)
            plt.xlabel('Iteration')
            plt.ylabel('Train loss')
            plt.plot(np.arange(iter_i), train_losses)

            plt.subplot(1, 2, 2)
            plt.xlabel('Iteration')
            plt.ylabel('Train acc')
            plt.plot(np.arange(iter_i), train_accuracies)

            plt.show()

  model.eval()

# %%
# создадим объекты модели и оптимизатор
rnn_raw = RecurrentRawAudioClassifier()
rnn_raw.to(device);

optim = torch.optim.Adam(rnn_raw.parameters(), lr=3e-4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-73531d214f15> in <module>()
#       1 # создадим объекты модели и оптимизатор
#       2 rnn_raw = RecurrentRawAudioClassifier()
# ----> 3 rnn_raw.to(device);
#       4
#       5 optim = torch.optim.Adam(rnn_raw.parameters(), lr=3e-4)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     671             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     672
# --> 673         return self._apply(convert)
#     674
#     675     def register_backward_hook(
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in _apply(self, fn)
#     184         self._flat_weights = [(lambda wn: getattr(self, wn) if hasattr(self, wn) else None)(wn) for wn in self._flat_weights_names]
#     185         # Flattens params (on CUDA)
# --> 186         self.flatten_parameters()
#     187
#     188         return ret
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in flatten_parameters(self)
#     174                         self.input_size, rnn.get_cudnn_mode(self.mode),
#     175                         self.hidden_size, self.proj_size, self.num_layers,  # type: ignore
# --> 176                         self.batch_first, bool(self.bidirectional))  # type: ignore
#     177
#     178     def _apply(self, fn):
#
# RuntimeError: cuDNN error: CUDNN_STATUS_NOT_INITIALIZED

# %%
# обучим модель
train_audio_clfr(rnn_raw, optim, train_dataloader, train_dataset.sr, num_epochs=3)

# %% [markdown]
# Посчитаем метрики на валидационном датасете.

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(model, val_dataloader, sr, device, data_transform=None):
  pred_true_pairs = []
  for batch in val_dataloader:
        x = batch['x'].to(device)
        y = batch['y'].to(device)
        lens = batch['len'].to(device)
        
        with torch.no_grad():
          if data_transform:
            x, lens = data_transform(x, lens, sr=sr, device=device)

          probs = model(x, lens)

          pred_cls = probs.argmax(dim=-1)

        for pred, true in zip(pred_cls.cpu().detach().numpy(), y.cpu().numpy()):
          pred_true_pairs.append((pred, true))

  print(f'Val accuracy: {np.mean([p[0] == p[1] for p in pred_true_pairs])}')

  cm_df = pd.DataFrame(
      confusion_matrix([p[1] for p in pred_true_pairs], 
                       [p[0] for p in pred_true_pairs], 
                       normalize='true'),
      columns=classes, index=classes)
  sn.heatmap(cm_df, annot=True)

# %%
plot_confusion_matrix(rnn_raw, val_dataloader, train_dataset.sr, device)

# %% [markdown]
# *Вопрос* : Сильно ли отличается качество модели на тренировочной и валидационной выборке? Если да, то как думаете, в чем причина?

# %% [markdown]
# ---
# Да, качество отличается довольно сильно, учитывая, что в тренировочной оно добивало до 0,6 уже на третьей эпохе (а к 9-ой становилось стабильно около 0,8), в то время как на валидации ограничилось ~20 процентами. Причина может быть в том, что мы используем сырой сигнал, потому любая разница в громкости и внешние шумы могут влиять на качество, а в нашем датасете такого очень много и фоновые шумы зачастую могут быть довольно громкими и существенно затруднять расползнавание основного класса. Также проблема может в несбалансированности классов

# %% [markdown]
# ## Задание 3. Построение Мел-cпектрограмм. (2 балла)
#
# Сырой сигнал очень чувствителен ко многим факторам - увеличение/уменьшение громкости, внешние шумы, сменение тембра говорящего очень резко меняют сырой сигнал. Это влияет и на качество глубоких сетей, обученных на сыром аудиосигнале.
#
# Для построения надежных и устойчивых к переобучению моделей используют другое представление аудиоданных - спектрограммы, в том числе Мел-спектрограмму.
#
# Идея её построения заключается в следующем:
# 1. Сигнал разбивается на временные интервалы (с пересечениями)
# 2. К каждому временному интервалу применяется фильтр (как правило косинусоидальный)
# 3. К профильтрованному сигналу применяется дискретное преобразование Фурье и вычисляются спектральные признаки сигнала.
# 4. Спектральные признаки с помощью логарифмического преобразования приводятся в Мел-шкалу.
#
# ![image](https://antkillerfarm.github.io/images/img2/Spectrogram_5.png)
#
# В этом задании мы сами шаг за шагом напишем алгоритм построения мелспектрограммы и сравнимся с референсной функцией из `torchaudio`.

# %%
from torchaudio.transforms import MelSpectrogram

# референсная функця
def compute_log_melspectrogram_reference(wav_batch, 
                                         lens,
                                         sr,
                                         device='cpu'):
  featurizer = MelSpectrogram(
      sample_rate=sr,
      n_fft=1024,
      win_length=1024,
      hop_length=256,
      n_mels=64,
      center=False,
      ).to(device)

  return torch.log(featurizer(wav_batch).clamp(1e-5)), lens // 256

# %%
# возьмем случайный батч
for batch in train_dataloader:
  break
wav_batch = batch['x']
lens = batch['len']

# посчитаем лог мелспектрограммы
log_melspect, lens = compute_log_melspectrogram_reference(wav_batch, lens, train_dataset.sr)

# нарисуем получившиеся референсные значения
fig, axes = plt.subplots(5, figsize=(16, 8))

for i in range(5):
  axes[i].axis('off')
  axes[i].set_title(f'Reference log melspectorgram {i}')
  axes[i].imshow(log_melspect[i].numpy())

# %% [markdown]
# Теперь сделаем то же самое сами.

# %%
sr = train_dataset.sr
n_fft=1024
win_length=1024
hop_length=256
n_mels=64

# %% [markdown]
# Для начала с помощью метода `unfold` разделим аудиосигнал на окна размера `win_lenght` через промежутки `hop_lenght`.

# %%
#windows = wav_batch.unfold(1, hop_length, win_length) 
windows = wav_batch.unfold(1, win_length, hop_length) 
assert windows.shape == (32, 1497, 1024)

# %% [markdown]
# Нарисуем и проиграем сигнал из одного окна.

# %%
plt.figure(figsize=(16, 8))
plt.plot(windows[0, 0])

display.Audio(windows[0, 0], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Теперь нам надо применить косинуисальный фильтр к сигналу из окна. Для этого с помощью `torch.hann_window` создадим косинусоидальный фильтр и умножим его поэлементно на все окна.

# %%
filter = torch.hann_window(win_length) # your code here
windows_with_applied_filter = windows * filter[None, None, :]

# %%
plt.figure(figsize=(16, 8))
plt.plot(windows_with_applied_filter[0, 0])

display.Audio(windows_with_applied_filter[0, 0], rate=train_dataset.sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# С помощью `torch.fft.fft` примените дискретное преобразование фурье к каждому окну и возьмите первые `n_fft // 2 + 1` компоненты.
#
# Дальше с помощью возведения элементов тензора в квадрат и `torch.abs()` получите магнитуды.

# %%
fft = torch.fft.fft(windows_with_applied_filter)
fft_features = fft[:, :, :n_fft // 2 + 1]
fft_magnitudes = torch.abs(fft_features ** 2)
assert fft_magnitudes.shape == (32, 1497, 513)

# %% [markdown]
# Через `torchaudio.transforms.MelScale` создайте класс для перевода магнитуд в Мел-шкалу.

# %%
n_mels = 64,
n_stft = 513
melscale =  torchaudio.transforms.MelScale(
    n_mels = 64,
    n_stft = 513, 
    sample_rate = sr
    #,norm=None
    )

# %% [markdown]
# Нелинейное преобразование для перевода в Мел-шкалу выглядит следующим образом.

# %%
plt.figure(figsize=(10, 5))
plt.axis('off')
plt.imshow(melscale.fb.numpy().transpose())

# %% [markdown]
# Примените Мел-шкалу к магнитудам.

# %%
fft_magnitudes.shape
# Out:
# torch.Size([32, 1497, 513])

# %%
fft_magnitudes.permute(0, -1, 1).shape
# Out:
# torch.Size([32, 513, 1497])

# %%
melscale(fft_magnitudes.permute(0, -1, 1)).shape
# Out:
# torch.Size([32, 64, 1497])

# %%
#magn_reshape = fft_magnitudes.permute(0, 1, -1)
magn_reshape = fft_magnitudes.permute(0, -1, 1)
mel_spectrogram = melscale(magn_reshape)
assert mel_spectrogram.shape == (32, 64, 1497)

# %% [markdown]
# Сделайте обрезку значений по `1e-5` и примените `torch.log` для получения логарифмированной Мел-спектрограммы.

# %%
cut_num = 1e-5
mel_cut = mel_spectrogram.clamp(cut_num)
logmel_spectrogram = torch.log(mel_cut)
assert logmel_spectrogram.shape == (32, 64, 1497)

# %% [markdown]
# Полученные логарифмированные Мел-Спектрограммы должны совпадать с референсными.

# %%
# нарисуем получившиеся значения
fig, axes = plt.subplots(5, figsize=(16, 8))

for i in range(5):
  axes[i].axis('off')
  axes[i].set_title(f'Your log melspectorgram {i}')
  axes[i].imshow(logmel_spectrogram[i].numpy())

# %% [markdown]
# Теперь оформим эту логику в функцию.

# %%
# ваша реализация
def compute_log_melspectrogram(wav_batch,
                               lens,
                               sr,
                               device='cpu'):
  ### YOUR CODE IS HERE ######
  melscale =  torchaudio.transforms.MelScale(
    n_mels = 64,
    n_stft = 513, 
    sample_rate = sr
    #,norm=None
    )
  
  filter = torch.hann_window(win_length) # your code here
  windows_with_applied_filter = windows * filter[None, None, :]

  n_fft = 1024
  fft = torch.fft.fft(windows_with_applied_filter)
  fft_features = fft[:, :, :n_fft // 2 + 1]
  fft_magnitudes = torch.abs(fft_features ** 2)

  magn_reshape = fft_magnitudes.permute(0, -1, 1)
  mel_spectrogram = melscale(magn_reshape)

  cut_num = 1e-5
  mel_cut = mel_spectrogram.clamp(cut_num)
  logmel_spectrogram = torch.log(mel_cut)

  return logmel_spectrogram, lens // 256 # делаем ретерн аналогичный compute_log_melspectrogram_reference


  ### THE END OF YOUR CODE ###

# %% [markdown]
# Финальная проверка.

# %%
assert torch.allclose(
    compute_log_melspectrogram_reference(wav_batch, lens, train_dataset.sr)[0],
    compute_log_melspectrogram(wav_batch, lens, train_dataset.sr)[0],
    atol=1e-5)

# %%
#  КУДА
def compute_log_melspectrogram_cuda(wav_batch,
                               lens,
                               sr,
                               device='cuda:0'):
  ### YOUR CODE IS HERE ######
  melscale =  torchaudio.transforms.MelScale(
    n_mels = 64,
    n_stft = 513, 
    sample_rate = sr
    #,norm=None
    ).to(device)

  filter = torch.hann_window(win_length).to(device) # your code here
  windows_with_applied_filter = windows.to(device) * filter[None, None, :].to(device)

  n_fft = 1024
  fft = torch.fft.fft(windows_with_applied_filter).to(device)
  fft_features = fft[:, :, :n_fft // 2 + 1].to(device)
  fft_magnitudes = torch.abs(fft_features ** 2).to(device)
  
  magn_reshape = fft_magnitudes.permute(0, -1, 1).to(device)
  mel_spectrogram = melscale(magn_reshape).to(device)

  cut_num = 1e-5
  mel_cut = mel_spectrogram.clamp(cut_num).to(device)
  logmel_spectrogram = torch.log(mel_cut).to(device)

  return logmel_spectrogram, lens // 256 # делаем ретерн аналогичный compute_log_melspectrogram_reference


  ### THE END OF YOUR CODE ###

# %% [markdown]
# ## Задание 4. Рекуррентная сеть для классификации аудиозаписей по логарифмированным Мел-спектрограммам (1 балл)
#
# Измените реализацию рекуррентной сети из задания 2, таким образом, чтобы она вместо сырого сигнала смогла принимать логарифмированные Мел-спетрограммы:
# 1. Уберите шаги 1-2
# 2. Сделайте вход LSTM равным 64
#
# ![arch_mel](https://github.com/aromana33/hw5_dl_2021/blob/main/images/rnn_mel.png?raw=1)
#
# **За реализацию архитектуры дается 0.5 балла.**

# %%
class RecurrentMelSpectClassifier(nn.Module):
  def __init__(self, 
               num_classes=10,
               window_length=1024,
               hop_length=256,
               hidden=256,
               num_layers=2):
    super().__init__()

    self.window_length = window_length
    self.hop_length = hop_length

    ### YOUR CODE IS HERE ######
    self.rnn = nn.LSTM(64, 
                       hidden, 
                       num_layers=2, 
                       bidirectional=True)

    self.final_mlp = nn.Sequential(
        nn.Linear(1024, 256),
        nn.BatchNorm1d(256), # c батчнормом получается побыстрей
        nn.ReLU(),
        nn.Linear(256, 10)
    ) 

    ### THE END OF YOUR CODE ###

  def forward(self, x, lens):
   ### YOUR CODE IS HERE ###### 

    # примените к получившемся последовательностям LSTM и возьмите hidden state
    wind = x.transpose(1, 2)
    lstm, (h,f) = self.rnn(wind.transpose(0, 1))

    # склейте hidden_state по слоям
    # hidden_flattened.shape = (B, 2 * hidden_size * num_layers)

    hidden_flattened = torch.cat((h[0], h[1], h[-2], h[-1]), dim=1)

    # примените полносвязную сеть и получим логиты классов
    return self.final_mlp(hidden_flattened)
   ### THE END OF YOUR CODE ###

# %%
rnn_mel = RecurrentMelSpectClassifier()
rnn_mel.to(device);

optim = torch.optim.Adam(rnn_mel.parameters(), lr=3e-4)

# %%
train_audio_clfr(rnn_mel, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram_cuda, num_epochs=10)
# Out:
# Epoch 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-48bc797c5501> in <module>()
#       1 train_audio_clfr(rnn_mel, optim, train_dataloader, train_dataset.sr,
# ----> 2                  data_transform=compute_log_melspectrogram_cuda, num_epochs=10)
#
# <ipython-input-14-43ec11b1a633> in train_audio_clfr(model, optimizer, train_dataloader, sr, criterion, data_transform, augmentation, num_epochs, device, verbose_num_iters)
#      31
#      32         # делаем предсказания
# ---> 33         probs = model(x, lens)
#      34
#      35         # делаем шаг градиента
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-87-f1df7a06550d> in forward(self, x, lens)
#      31     # примените к получившемся последовательностям LSTM и возьмите hidden state
#      32     wind = x.transpose(1, 2)
# ---> 33     lstm, (h,f) = self.rnn(wind.transpose(0, 1))
#      34
#      35     # склейте hidden_state по слоям
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     660         if batch_sizes is None:
#     661             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 662                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     663         else:
#     664             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %% [markdown]
# Посчитаем метрики на валидационном датасете.

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор гиперпараметров и добейтесь accuracy модели выше 0.8 на валидационном датасете.**

# %%
plot_confusion_matrix(rnn_mel, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram_cuda)
# Out:
# Val accuracy: 0.12513368983957218

# %% [markdown]
# ## Задание 5. Cверточная сеть для классификации аудиозаписей по мелспектрограммам. (2 балла)
#
# Легко заметить, что мелспектрограммы имеют четко выраженные паттерны - если приноровиться, то даже человек, посмотрев на мелспектрограмму, сможет _визуально_ проклассифицировать объект.
#
# Это позволяет свести задачу классификации аудиозаписей к задаче классификации картинок.
#
# Реализуем такую сверточную сеть:
#
# * 2x (Conv2d 3x3 @ 16, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * 2x (Conv2d 3x3 @ 32, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * 2x (Conv2d 3x3 @ 64, BatchNorm2d, ReLU)
# * MaxPoll 2x2
# * (Conv2d 3x3 @ 128, BatchNorm2d, ReLU)
# * (Conv2d 2x2 @ 128, BatchNorm2d, ReLU)
# * Global MaxPoll
# * Fully Connected 128, ReLU
# * Fully Connected 10
#
# Совет: подобная архитектура была реализована в [**PANNs: Large-Scale Pretrained Audio Neural Networks for Audio Pattern Recognition**](https://arxiv.org/pdf/1912.10211.pdf), можете использовать эту статью как референс.
#
#
# **За реализацию архитектуры дается 1.5 балла.**

# %%
class CNN10(nn.Module):
  def __init__(self, num_classes=10, hidden=16):
    super().__init__()

    ### YOUR CODE IS HERE ######
    self.cnn_backbone = nn.Sequential(
        nn.Conv2d(in_channels=1, 
                  out_channels=16, kernel_size=3),
        nn.BatchNorm2d(16),
        nn.ReLU(),
        nn.Conv2d(in_channels=16, 
                  out_channels=16, kernel_size=3),
        nn.BatchNorm2d(16),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),
        nn.Conv2d(in_channels=16, 
                  out_channels=32, kernel_size=3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.Conv2d(in_channels=32, 
                  out_channels=32, kernel_size=3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),
        nn.Conv2d(in_channels=32, 
                  out_channels=64, kernel_size=3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.Conv2d(in_channels=64, 
                  out_channels=64, kernel_size=3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),
        nn.Conv2d(in_channels=64, 
                  out_channels=128, kernel_size=3),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, 
                  out_channels=128, kernel_size=2),
        nn.BatchNorm2d(128),
        nn.ReLU()
    )

    self.final_mlp = nn.Sequential(
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, 10)
        
    )
    ### THE END OF YOUR CODE ###

  def forward(self, x, lens):
    z = self.cnn_backbone(x[:, None, :, :])
    z = torch.nn.functional.max_pool2d(z, kernel_size=z.size()[2:])[:, :, 0, 0]
    return self.final_mlp(z)

# %%
cnn = CNN10()
cnn.to(device);

optim = torch.optim.Adam(cnn.parameters(), lr=3e-4)

# %%
train_audio_clfr(cnn, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram_cuda,
                 num_epochs=20)
# Out:
# Epoch 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-7b1bf75fc959> in <module>()
#       1 train_audio_clfr(cnn, optim, train_dataloader, train_dataset.sr,
#       2                  data_transform=compute_log_melspectrogram_cuda,
# ----> 3                  num_epochs=20)
#
# <ipython-input-14-43ec11b1a633> in train_audio_clfr(model, optimizer, train_dataloader, sr, criterion, data_transform, augmentation, num_epochs, device, verbose_num_iters)
#      14
#      15   for epoch in range(num_epochs):
# ---> 16     for batch in train_dataloader:
#      17         x = batch['x'].to(device)
#      18         y = batch['y'].to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-7-feba69d93baf> in __getitem__(self, index)
#      24         path = str(self.path_to_folder) + end
#      25
# ---> 26         wav, sr = torchaudio.load(path)
#      27         if sr != self.sr:
#      28             resampler = torchaudio.transforms.Resample(sr, self.sr)
#
# /usr/local/lib/python3.7/dist-packages/torchaudio/backend/sox_io_backend.py in load(filepath, frame_offset, num_frames, normalize, channels_first, format)
#     149         filepath = os.fspath(filepath)
#     150     return torch.ops.torchaudio.sox_io_load_audio_file(
# --> 151         filepath, frame_offset, num_frames, normalize, channels_first, format)
#     152
#     153
#
# KeyboardInterrupt:

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор гиперпараметров и добейтесь accuracy модели выше 0.85 на валидационном датасете.**

# %%
plot_confusion_matrix(cnn, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram_cuda)
# Out:
# Val accuracy: 0.11336898395721925

# %% [markdown]
# ## Задание 6. Аугментация SpecAugment (2 балла)
#
# Обычно датасеты с аудиозаписями довольно малы. Наш датасет тому пример - всего 4500 объектов в обучающей выборке. Обучение глубокий сетей с большим кол-вом параметров на таких датасетах часто ведет к переобучению и проседанию метрик на валидационном и тестовом датасетах.
#
# Для борьбы с переобучением имеет смысл использовать аугментацию данных. Для мелспектрограмм была придумана аугментация под названием SpecAugment.
#
# Смысл её очень прост - зануление спектрограммы по временным промежуткам и по мел-частотам:
# 1. Выбираются несколько временных промежутков ${[t^1_i, t^2_i]}$ и заполняют спектрограмму $s[t^1_i : t^2_i, :]$ значением $v$.
#
# 2. Выбираются несколько промежутков мелчастот ${[m^1_i, m^2_i]}$ и заполняют спектрограмму $s[:, m^1_i : m^2_i]$ значением $v$.
#
# В качестве значения $v$ выбирают:
# 1. `'mean'`: среднее по спектрограмме
# 2. `'min'`: минимум по спектрограмме
# 3. `'max'`: максимум по спектрограмме
# 5. `v`: некоторая константа
#
# Совет: описание аугментации можно найти здесь: [link](https://neurohive.io/ru/novosti/specaugment-novyj-metod-augmentacii-audiodannyh-ot-google-ai/), можете использовать эту ссылку как референс.
#
# ![specaugment](https://neurohive.io/wp-content/uploads/2019/04/image6.png)
#
# В этом задании Вам предлагается реализовать аугментацию SpecAugment.
#
# **За реализацию аугментации дается 1.5 балла.**

# %%
import random


class SpectAugment:
    def __init__(
        self,
        filling_value = 'mean',
        n_freq_masks = 2,
        n_time_masks = 2,
        max_freq = 10,
        max_time = 50,
    ):

        self.filling_value = filling_value
        self.n_freq_masks = n_freq_masks
        self.n_time_masks = n_time_masks
        self.max_freq = max_freq
        self.max_time = max_time

    def __call__(self, spect, lens):
        ### YOUR CODE IS HERE ######
        
        ### THE END OF YOUR CODE ###

# %%
# применим аугментацию к данным
for batch in train_dataloader:
  break

x = batch['x'].to(device)
lens = batch['len'].to(device)
x_logmel, lens = compute_log_melspectrogram_reference(x, lens, sr=train_dataset.sr, device=device)
x_logmel_augmented, lens = SpectAugment()(x_logmel, lens)

# нарисуем спектрограмму до и после аугментации
plt.figure(figsize=(20, 5))
plt.subplot(2, 1, 1)
plt.title('Original log MelSpectrogram')
plt.axis('off')
plt.imshow(x_logmel[0].cpu().numpy())

plt.subplot(2, 1, 2)
plt.title('Augmented log MelSpectrogram')
plt.axis('off')
plt.imshow(x_logmel_augmented[0].cpu().numpy())

# %%
cnn = CNN10()
cnn.to(device);

optim = torch.optim.Adam(cnn.parameters(), lr=3e-4)

# %%
# обучим модель на данных с аугментациями
train_audio_clfr(cnn, optim, train_dataloader, train_dataset.sr, 
                 data_transform=compute_log_melspectrogram,
                 augmentation=SpectAugment(),
                 num_epochs=20)

# %% [markdown]
# **Задание: для получения 0.5 балла сделайте подбор параметров аугментации и добейтесь accuracy модели выше 0.9 на валидационном датасете.**

# %%
plot_confusion_matrix(cnn, val_dataloader, train_dataset.sr, device, 
                      data_transform=compute_log_melspectrogram)
